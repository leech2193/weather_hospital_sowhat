# %%
import numpy as np
import pandas as pd
from itertools import *
from pycaret.regression import *

# %%
dataset2 = pd.read_csv('Z:/공모전/날씨빅데이터콘테스트(공유)/data/hospital_female_0725.csv', encoding='cp949')
dataset2.mm = dataset2.mm.astype('int64')
fixed_df = dataset2[['area', 'mm', 'weekday', 'frequency','total_pop', 'elderly_ratio','so2','pm10','rhm_min_avg_dif','min_max_Ta','avg_ps']]

sub_df = [ dataset2[['o3']], dataset2[['avg_age']], dataset2[['avg_ta']], dataset2[['sum_gsr']], dataset2[['sum_rn']], dataset2[['avg_rhm']] ]
sub_list = list(combinations(sub_df, 2))
sub_list[2][0]

for i in range(len(sub_df)):
    sub_list = list(combinations(sub_df, i+1))
    for j in range(len(sub_list)):
        dataset_df = fixed_df.copy()
        for k in sub_list[j]:
            dataset_df = pd.concat([dataset_df,k], axis=1)
        
        print(dataset_df.columns)
        print('log')
        data = dataset_df.sample(frac=0.9, random_state=786) 
        data_unseen = dataset_df.drop(data.index) 

        data.reset_index(drop=True, inplace=True) 
        data_unseen.reset_index(drop=True, inplace=True) 

        print('Data for Modeling: ' + str(data.shape)) 
        print('Unseen Data For Predictions: ' + str(data_unseen.shape)) 
        
        s = setup(data, target = 'frequency', silent=True, session_id=123)
        
        best_model_5 = compare_models(sort='RMSE', n_select = 5)
        
        final_model = finalize_model(best_model_5[0])
        prediction = predict_model(final_model, data = data_unseen)
        print(prediction['Label'])
# Out:
# <style type="text/css">
# #T_c8b92 th {
#   text-align: left;
# }
# #T_c8b92_row0_col0, #T_c8b92_row0_col6, #T_c8b92_row1_col0, #T_c8b92_row1_col1, #T_c8b92_row1_col2, #T_c8b92_row1_col3, #T_c8b92_row1_col4, #T_c8b92_row1_col5, #T_c8b92_row1_col6, #T_c8b92_row2_col0, #T_c8b92_row2_col1, #T_c8b92_row2_col2, #T_c8b92_row2_col3, #T_c8b92_row2_col4, #T_c8b92_row2_col5, #T_c8b92_row2_col6, #T_c8b92_row3_col0, #T_c8b92_row3_col1, #T_c8b92_row3_col2, #T_c8b92_row3_col3, #T_c8b92_row3_col4, #T_c8b92_row3_col5, #T_c8b92_row3_col6, #T_c8b92_row4_col0, #T_c8b92_row4_col1, #T_c8b92_row4_col2, #T_c8b92_row4_col3, #T_c8b92_row4_col4, #T_c8b92_row4_col5, #T_c8b92_row4_col6, #T_c8b92_row5_col0, #T_c8b92_row5_col1, #T_c8b92_row5_col2, #T_c8b92_row5_col3, #T_c8b92_row5_col4, #T_c8b92_row5_col5, #T_c8b92_row5_col6, #T_c8b92_row6_col0, #T_c8b92_row6_col1, #T_c8b92_row6_col2, #T_c8b92_row6_col3, #T_c8b92_row6_col4, #T_c8b92_row6_col5, #T_c8b92_row6_col6, #T_c8b92_row7_col0, #T_c8b92_row7_col1, #T_c8b92_row7_col2, #T_c8b92_row7_col3, #T_c8b92_row7_col4, #T_c8b92_row7_col5, #T_c8b92_row7_col6, #T_c8b92_row8_col0, #T_c8b92_row8_col1, #T_c8b92_row8_col2, #T_c8b92_row8_col3, #T_c8b92_row8_col4, #T_c8b92_row8_col5, #T_c8b92_row8_col6, #T_c8b92_row9_col0, #T_c8b92_row9_col1, #T_c8b92_row9_col2, #T_c8b92_row9_col3, #T_c8b92_row9_col4, #T_c8b92_row9_col5, #T_c8b92_row9_col6, #T_c8b92_row10_col0, #T_c8b92_row10_col1, #T_c8b92_row10_col2, #T_c8b92_row10_col3, #T_c8b92_row10_col4, #T_c8b92_row10_col5, #T_c8b92_row11_col0, #T_c8b92_row11_col1, #T_c8b92_row11_col2, #T_c8b92_row11_col3, #T_c8b92_row11_col4, #T_c8b92_row11_col5, #T_c8b92_row11_col6, #T_c8b92_row12_col0, #T_c8b92_row12_col1, #T_c8b92_row12_col2, #T_c8b92_row12_col3, #T_c8b92_row12_col4, #T_c8b92_row12_col5, #T_c8b92_row12_col6, #T_c8b92_row13_col0, #T_c8b92_row13_col1, #T_c8b92_row13_col2, #T_c8b92_row13_col3, #T_c8b92_row13_col4, #T_c8b92_row13_col5, #T_c8b92_row13_col6, #T_c8b92_row14_col0, #T_c8b92_row14_col1, #T_c8b92_row14_col2, #T_c8b92_row14_col3, #T_c8b92_row14_col4, #T_c8b92_row14_col5, #T_c8b92_row14_col6, #T_c8b92_row15_col0, #T_c8b92_row15_col1, #T_c8b92_row15_col2, #T_c8b92_row15_col3, #T_c8b92_row15_col4, #T_c8b92_row15_col5, #T_c8b92_row15_col6, #T_c8b92_row16_col0, #T_c8b92_row16_col1, #T_c8b92_row16_col2, #T_c8b92_row16_col3, #T_c8b92_row16_col4, #T_c8b92_row16_col5, #T_c8b92_row16_col6, #T_c8b92_row17_col0, #T_c8b92_row17_col1, #T_c8b92_row17_col2, #T_c8b92_row17_col3, #T_c8b92_row17_col4, #T_c8b92_row17_col5, #T_c8b92_row17_col6, #T_c8b92_row18_col0, #T_c8b92_row18_col1, #T_c8b92_row18_col2, #T_c8b92_row18_col3, #T_c8b92_row18_col4, #T_c8b92_row18_col5, #T_c8b92_row18_col6, #T_c8b92_row19_col0, #T_c8b92_row19_col1, #T_c8b92_row19_col2, #T_c8b92_row19_col3, #T_c8b92_row19_col4, #T_c8b92_row19_col5, #T_c8b92_row19_col6 {
#   text-align: left;
# }
# #T_c8b92_row0_col1, #T_c8b92_row0_col2, #T_c8b92_row0_col3, #T_c8b92_row0_col4, #T_c8b92_row0_col5, #T_c8b92_row10_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c8b92_row0_col7, #T_c8b92_row1_col7, #T_c8b92_row2_col7, #T_c8b92_row3_col7, #T_c8b92_row4_col7, #T_c8b92_row5_col7, #T_c8b92_row6_col7, #T_c8b92_row7_col7, #T_c8b92_row8_col7, #T_c8b92_row9_col7, #T_c8b92_row10_col7, #T_c8b92_row11_col7, #T_c8b92_row12_col7, #T_c8b92_row13_col7, #T_c8b92_row14_col7, #T_c8b92_row15_col7, #T_c8b92_row17_col7, #T_c8b92_row18_col7, #T_c8b92_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c8b92_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c8b92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8b92_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c8b92_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c8b92_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c8b92_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c8b92_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c8b92_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c8b92_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c8b92_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8b92_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_c8b92_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_c8b92_row0_col1" class="data row0 col1" >0.8978</td>
#       <td id="T_c8b92_row0_col2" class="data row0 col2" >1.5003</td>
#       <td id="T_c8b92_row0_col3" class="data row0 col3" >1.2246</td>
#       <td id="T_c8b92_row0_col4" class="data row0 col4" >0.4502</td>
#       <td id="T_c8b92_row0_col5" class="data row0 col5" >0.4817</td>
#       <td id="T_c8b92_row0_col6" class="data row0 col6" >0.4487</td>
#       <td id="T_c8b92_row0_col7" class="data row0 col7" >2.2340</td>
#     </tr>
#     <tr>
#       <th id="T_c8b92_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_c8b92_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_c8b92_row1_col1" class="data row1 col1" >0.9031</td>
#       <td id="T_c8b92_row1_col2" class="data row1 col2" >1.5013</td>
#       <td id="T_c8b92_row1_col3" class="data row1 col3" >1.2250</td>
#       <td id="T_c8b92_row1_col4" class="data row1 col4" >0.4500</td>
#       <td id="T_c8b92_row1_col5" class="data row1 col5" >0.4844</td>
#       <td id="T_c8b92_row1_col6" class="data row1 col6" >0.4581</td>
#       <td id="T_c8b92_row1_col7" class="data row1 col7" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_c8b92_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_c8b92_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_c8b92_row2_col1" class="data row2 col1" >0.9037</td>
#       <td id="T_c8b92_row2_col2" class="data row2 col2" >1.5016</td>
#       <td id="T_c8b92_row2_col3" class="data row2 col3" >1.2252</td>
#       <td id="T_c8b92_row2_col4" class="data row2 col4" >0.4499</td>
#       <td id="T_c8b92_row2_col5" class="data row2 col5" >0.4845</td>
#       <td id="T_c8b92_row2_col6" class="data row2 col6" >0.4563</td>
#       <td id="T_c8b92_row2_col7" class="data row2 col7" >0.1010</td>
#     </tr>
#     <tr>
#       <th id="T_c8b92_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_c8b92_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_c8b92_row3_col1" class="data row3 col1" >0.9066</td>
#       <td id="T_c8b92_row3_col2" class="data row3 col2" >1.5053</td>
#       <td id="T_c8b92_row3_col3" class="data row3 col3" >1.2267</td>
#       <td id="T_c8b92_row3_col4" class="data row3 col4" >0.4485</td>
#       <td id="T_c8b92_row3_col5" class="data row3 col5" >0.4861</td>
#       <td id="T_c8b92_row3_col6" class="data row3 col6" >0.4557</td>
#       <td id="T_c8b92_row3_col7" class="data row3 col7" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_c8b92_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_c8b92_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c8b92_row4_col1" class="data row4 col1" >0.9013</td>
#       <td id="T_c8b92_row4_col2" class="data row4 col2" >1.5271</td>
#       <td id="T_c8b92_row4_col3" class="data row4 col3" >1.2354</td>
#       <td id="T_c8b92_row4_col4" class="data row4 col4" >0.4404</td>
#       <td id="T_c8b92_row4_col5" class="data row4 col5" >0.4842</td>
#       <td id="T_c8b92_row4_col6" class="data row4 col6" >0.4523</td>
#       <td id="T_c8b92_row4_col7" class="data row4 col7" >0.1700</td>
#     </tr>
#     <tr>
#       <th id="T_c8b92_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_c8b92_row5_col0" class="data row5 col0" >CatBoost Regressor</td>
#       <td id="T_c8b92_row5_col1" class="data row5 col1" >0.9108</td>
#       <td id="T_c8b92_row5_col2" class="data row5 col2" >1.5427</td>
#       <td id="T_c8b92_row5_col3" class="data row5 col3" >1.2417</td>
