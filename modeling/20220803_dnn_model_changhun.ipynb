# %%
import tensorflow as tf
import numpy      as np
import pandas     as pd
import seaborn    as sns

import matplotlib.pyplot as plt

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

from   sklearn.model_selection import train_test_split , KFold, StratifiedKFold, cross_val_score, cross_validate, GridSearchCV

from   sklearn.metrics         import accuracy_score , precision_score , recall_score , f1_score , confusion_matrix , precision_recall_curve, roc_curve, roc_auc_score

from   sklearn.metrics         import mean_squared_error, mean_absolute_error, r2_score

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA, IncrementalPCA

from   sklearn.preprocessing   import LabelEncoder , OneHotEncoder , MinMaxScaler , StandardScaler , Binarizer, PolynomialFeatures, RobustScaler

from   sklearn.linear_model    import LogisticRegression , LinearRegression    

from sklearn.neighbors import KNeighborsRegressor

from sklearn.model_selection import KFold
from   sklearn.svm             import SVC, SVR, LinearSVR
from   lightgbm                import LGBMRegressor
# from sklearn. import LinearRegression

# %%
def regression_model_predict(model, X_train, X_test, y_train, y_test, isFlag = False ) :
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    if isFlag :
        y_test = np.expm1(y_test)
        pred = np.expm1(pred)
    print(model.__class__.__name__, '-->')
    
    regression_eval(y_test, pred)

def regression_eval(y_test, y_pred) :
    print('회귀 평가 지표 확인 - ')
    print('MAE   - ' , mean_absolute_error(y_test, y_pred))
    print('MSE   - ' , mean_squared_error(y_test, y_pred))
    print('RMSE  - ' , np.sqrt(mean_squared_error(y_test, y_pred)))
    print('R2 SCORE - ', r2_score(y_test, y_pred))
    
    # rmsle 언더플로우 영향으로 로그변환이 필요함
    log_y    = np.log1p(y_test)
    log_pred = np.log1p(y_pred)
    error    = (log_y - log_pred) ** 2
    print('RMSLE - ' ,  np.sqrt(np.mean(error)))
    print()

# %%
result_frm = pd.DataFrame({'Category':['Model_NM','Model_NM_2','Params', 'MAE','MSE','RMSE','R2_SCORE','RMSLE']})


def regression_predict_eval_frm(model, X_train, X_test, y_train, y_test, isFlag = False) :
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    if isFlag :
        y_test = np.expm1(y_test)
        y_pred = np.expm1(y_pred)
    print(model.__class__.__name__, '-->')
    
    print('회귀 평가 지표 확인 - ')
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2score = r2_score(y_test, y_pred)
    print('MAE      - ' , mae)
    print('MSE      - ' , mse)
    print('RMSE     - ' , rmse)
    print('R2 SCORE - ', r2score)
    
    # rmsle 언더플로우 영향으로 로그변환이 필요함
    log_y    = np.log1p(y_test)
    log_pred = np.log1p(y_pred)
    error    = (log_y - log_pred) ** 2
    rmsle = np.sqrt(np.mean(error))
    print('RMSLE - ' , rmsle)
    print()
    msg = list(X_data.columns)
#     msg = input('any message?')
    # dataframe 에 결과값 추가
    result_frm[result_frm.shape[1]] = [model.__class__.__name__, msg, model.get_params(), 
                                      mae, mse, rmse, r2score, rmsle]
    display(result_frm)

# %%
hospital_female = pd.read_csv('./hospital_female_0802_test3.csv', encoding='cp949')
hospital_female = hospital_female[hospital_female['yyyy'].astype(str).str.contains('2012|2013|2014|2015')].reset_index(drop=True)#2016년 전만 추출

# %%
hospital_female
# Out:
#       area         tma  yyyy  mm  dd  weekday   sum_gsr    sum_rn  \
# 0       강원  2012-01-01  2012   1   1        6  0.000000  0.173611
# 1       경기  2012-01-01  2012   1   1        6  0.000000  0.037736
# 2       경남  2012-01-01  2012   1   1        6  0.000000  0.065789
# 3       경북  2012-01-01  2012   1   1        6  0.000702  0.721053
# 4       광주  2012-01-01  2012   1   1        6  0.000000  0.700000
# ...    ...         ...   ...  ..  ..      ...       ...       ...
# 24832   전남  2015-12-31  2015  12  31        3  0.000000  1.608108
# 24833   전북  2015-12-31  2015  12  31        3  1.305806  0.967742
# 24834   제주  2015-12-31  2015  12  31        3  0.000000  0.971429
# 24835   충남  2015-12-31  2015  12  31        3  1.757273  0.196970
# 24836   충북  2015-12-31  2015  12  31        3  0.000000  0.096154
#
#             avg_ps       max_ps  ...  diff_hum  min_temp  max_temp  avg_temp  \
# 0      1023.886667  1026.533333  ...      65.0      -7.3       5.0 -2.344048
# 1      1024.875000  1027.225000  ...      27.0      -6.9       1.0 -3.010000
# 2      1022.950000  1024.900000  ...      47.0      -2.9       7.0  1.642857
# 3      1023.268000  1025.488000  ...      70.0      -5.9       6.1  0.075556
# 4      1025.250000  1027.250000  ...      15.0      -0.9       3.0  0.383333
# ...            ...          ...  ...       ...       ...       ...       ...
# 24832  1031.053846  1034.280769  ...      65.0      -2.3      10.0  4.105198
# 24833  1031.300000  1034.478571  ...      50.0      -3.0       7.0  2.132162
# 24834  1030.792308  1034.553846  ...      33.0       5.4      10.3  7.709797
# 24835  1031.513333  1034.120000  ...      55.0      -3.0       6.0  1.345383
# 24836  1030.850000  1034.400000  ...      55.0      -4.0       6.1  0.642230
#
#        diff_temp     pm10_3b    pm10_7b   pm10_31b  frequency  fat_rate
# 0           12.3   87.662500  30.158333  15.678261        3.0      26.7
# 1            7.9  106.851851  28.537404  13.474891        5.0      24.6
# 2            9.9   72.989269  26.719907  16.193461        1.0      22.5
# 3           12.0   88.189236  25.336806  12.743785        1.0      23.7
# 4            3.9   62.750000  18.958333   8.566667        2.0      22.6
# ...          ...         ...        ...        ...        ...       ...
# 24832       12.3   23.382672  46.708333  48.514658        3.0      25.4
# 24833       10.0   36.292835  72.548882  56.803399        0.0      25.7
# 24834        4.9   27.340580  56.156250  48.416667        0.0      28.5
# 24835        9.0   28.104167  79.543252  45.036458        0.0      26.4
# 24836       10.1   33.789583  74.573958  56.070265        0.0      26.5
#
# [24837 rows x 36 columns]

# %%
# hospital2 = hospital.drop(['date', 'precipitation duration(hr)', 'female population', 'male population', 'total population'], axis=1)

# %%
hospital_female.columns
# Out:
# Index(['area', 'tma', 'yyyy', 'mm', 'dd', 'weekday', 'sum_gsr', 'sum_rn',
#        'avg_ps', 'max_ps', 'min_ps', 'so2', 'o3', 'pm10', 'sex', 'elderly_pop',
#        'total_pop', 'elderly_ratio', 'avg_age', 'min_max_ps', 'D/R',
#        'heat_wave', 'cold_wave', 'min_hum', 'max_hum', 'avg_hum', 'diff_hum',
#        'min_temp', 'max_temp', 'avg_temp', 'diff_temp', 'pm10_3b', 'pm10_7b',
#        'pm10_31b', 'frequency', 'fat_rate'],
#       dtype='object')

# %%
hospital_female2 = hospital_female[[
    'area', 'mm', 'weekday', 'sum_rn',
       'avg_ps', 'o3',
       'total_pop', 'elderly_ratio', 'avg_age', 'min_max_ps',
       'heat_wave', 'cold_wave', 'diff_hum',
        'diff_temp', 'pm10_7b', 'frequency']]

# %%
mapping = {'강원':0, '경기':1, '경남':2, '경북':3, '광주':4, '대구':5,
           '대전':6, '부산':7, '서울':8, '울산':9, '인천':10,
           '전남':11, '전북':12, '제주':13, '충남':14, '충북':15, '세종':16}

# %%
hospital_female2.insert(1, 'area_label', hospital_female2['area'].map(mapping))

# %%
hospital_female2.drop(columns=['area'], inplace=True)
# Out:
# /var/folders/f5/x0_185757lld2fhv6ygmb8f40000gn/T/ipykernel_40745/3562702183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital_female2.drop(columns=['area'], inplace=True)

# %%
hospital_female2
# Out:
#        area_label  mm  weekday    sum_rn       avg_ps        o3  total_pop  \
# 0               0   1        6  0.173611  1023.886667  0.027750     762617
# 1               1   1        6  0.037736  1024.875000  0.023165    5928150
# 2               2   1        6  0.065789  1022.950000  0.027277    1644251
# 3               3   1        6  0.721053  1023.268000  0.027274    1342455
# 4               4   1        6  0.700000  1025.250000  0.027300     738784
# ...           ...  ..      ...       ...          ...       ...        ...
# 24832          11  12        3  1.608108  1031.053846  0.035985     955115
# 24833          12  12        3  0.967742  1031.300000  0.028738     939456
# 24834          13  12        3  0.971429  1030.792308  0.044719     310967
# 24835          14  12        3  0.196970  1031.513333  0.024484    1023210
# 24836          15  12        3  0.096154  1030.850000  0.018966     785056
#
#        elderly_ratio  avg_age  min_max_ps  heat_wave  cold_wave  diff_hum  \
# 0          18.053361     42.4    6.340000          0          0      65.0
# 1          10.649039     37.7    5.500000          0          0      27.0
# 2          15.076105     40.5    5.200000          0          0      47.0
# 3          19.248690     43.2    5.688000          0          0      70.0
# 4          11.037868     37.6    4.100000          0          0      15.0
# ...              ...      ...         ...        ...        ...       ...
# 24832      24.847060     45.9    6.892308          0          0      65.0
# 24833      21.104873     44.2    7.014286          0          0      50.0
# 24834      16.470236     41.5    7.523077          0          0      33.0
# 24835      19.459055     43.1    6.800000          0          0      55.0
# 24836      17.517604     42.7    7.050000          0          0      55.0
#
#        diff_temp    pm10_7b  frequency
# 0           12.3  30.158333        3.0
# 1            7.9  28.537404        5.0
# 2            9.9  26.719907        1.0
# 3           12.0  25.336806        1.0
# 4            3.9  18.958333        2.0
# ...          ...        ...        ...
# 24832       12.3  46.708333        3.0
# 24833       10.0  72.548882        0.0
# 24834        4.9  56.156250        0.0
# 24835        9.0  79.543252        0.0
# 24836       10.1  74.573958        0.0
#
# [24837 rows x 16 columns]

# %%
X_data = hospital_female2.drop(['frequency'], axis=1)
y_data = hospital_female2[['frequency']]

print('X_data')
display(X_data.head())
print('y_data')
display(y_data.head())
# Out:
# X_data
#    area_label  mm  weekday    sum_rn       avg_ps        o3  total_pop  \
# 0           0   1        6  0.173611  1023.886667  0.027750     762617
# 1           1   1        6  0.037736  1024.875000  0.023165    5928150
# 2           2   1        6  0.065789  1022.950000  0.027277    1644251
# 3           3   1        6  0.721053  1023.268000  0.027274    1342455
# 4           4   1        6  0.700000  1025.250000  0.027300     738784
#
#    elderly_ratio  avg_age  min_max_ps  heat_wave  cold_wave  diff_hum  \
# 0      18.053361     42.4       6.340          0          0      65.0
# 1      10.649039     37.7       5.500          0          0      27.0
# 2      15.076105     40.5       5.200          0          0      47.0
# 3      19.248690     43.2       5.688          0          0      70.0
# 4      11.037868     37.6       4.100          0          0      15.0
#
#    diff_temp    pm10_7b
# 0       12.3  30.158333
# 1        7.9  28.537404
# 2        9.9  26.719907
# 3       12.0  25.336806
# 4        3.9  18.958333
# y_data
#    frequency
# 0        3.0
# 1        5.0
# 2        1.0
# 3        1.0
# 4        2.0

# %%
# X_data scaling : normalization (MinMaxScaler) // y_data scaling : log
n_scaler = MinMaxScaler()
X_scaled = n_scaler.fit_transform(X_data)

# y_data scaling : log1p
y_scaled = np.log1p(y_data)

# %%
# lda = LinearDiscriminantAnalysis(n_components=5)
# pca = PCA(n_components='mle') # pca 이용해서 진행

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, 
                                                    y_scaled['frequency'],
                                                   test_size = .2,
                                                    shuffle=True,
                                                   random_state = 1)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((19869, 15), (4968, 15), (19869,), (4968,))

# %%
# pca.fit(X_train)
# train_reduced = pca.fit_transform(X_train)
# test_reduced = pca.transform(X_test)

# %%
hospital_female2.isnull().sum()
# Out:
# area_label       0
# mm               0
# weekday          0
# sum_rn           0
# avg_ps           0
# o3               0
# total_pop        0
# elderly_ratio    0
# avg_age          0
# min_max_ps       0
# heat_wave        0
# cold_wave        0
# diff_hum         0
# diff_temp        0
# pm10_7b          0
# frequency        0
# dtype: int64

# %%
poly = PolynomialFeatures(degree=3, include_bias=False)

poly.fit(X_train)
train_poly = poly.transform(X_train)
test_poly  = poly.transform(X_test)

# %%
svr = SVR(kernel='rbf')
svr.fit(train_poly, y_train)

regression_predict_eval_frm(svr, train_poly, test_poly, y_train, y_test, isFlag=True)
result_frm.to_csv('./result_frm.csv', encoding='utf-8')
# Out:
# SVR -->
# 회귀 평가 지표 확인 -
# MAE      -  0.884763474788205
# MSE      -  1.543849338047396
# RMSE     -  1.2425173391335012
# R2 SCORE -  0.4205640450588555
# RMSLE -  0.4751079173613276
#      Category                                                  1  \
# 0    Model_NM                                                SVR
# 1  Model_NM_2  [area_label, yyyy, mm, dd, weekday, sum_rn, av...
# 2      Params  {'C': 1.0, 'cache_size': 200, 'coef0': 0.0, 'd...
# 3         MAE                                           0.886374
# 4         MSE                                           1.539807
# 5        RMSE                                            1.24089
# 6    R2_SCORE                                           0.422081
# 7       RMSLE                                           0.475954
#
#                                                    2
# 0                                                SVR
# 1  [area_label, mm, weekday, sum_rn, avg_ps, o3, ...
# 2  {'C': 1.0, 'cache_size': 200, 'coef0': 0.0, 'd...
# 3                                           0.884763
# 4                                           1.543849
# 5                                           1.242517
# 6                                           0.420564
# 7                                           0.475108

# %%
lgbm = LGBMRegressor()
lgbm.fit(train_poly, y_train)
regression_predict_eval_frm(lgbm, train_poly, test_poly, y_train, y_test, isFlag=True)
result_frm.to_csv('./result_frm.csv', encoding='utf-8')
# Out:
# LGBMRegressor -->
# 회귀 평가 지표 확인 -
# MAE      -  0.9019249806969999
# MSE      -  1.6017190839589823
# RMSE     -  1.265590409239491
# R2 SCORE -  0.3988444311962158
# RMSLE -  0.4735889182357715
#      Category                                                  1  \
# 0    Model_NM                                                SVR
# 1  Model_NM_2  [area_label, yyyy, mm, dd, weekday, sum_rn, av...
# 2      Params  {'C': 1.0, 'cache_size': 200, 'coef0': 0.0, 'd...
# 3         MAE                                           0.886374
# 4         MSE                                           1.539807
# 5        RMSE                                            1.24089
# 6    R2_SCORE                                           0.422081
# 7       RMSLE                                           0.475954
#
#                                                    2  \
# 0                                                SVR
# 1  [area_label, mm, weekday, sum_rn, avg_ps, o3, ...
# 2  {'C': 1.0, 'cache_size': 200, 'coef0': 0.0, 'd...
# 3                                           0.884763
# 4                                           1.543849
# 5                                           1.242517
# 6                                           0.420564
# 7                                           0.475108
#
#                                                    3
# 0                                      LGBMRegressor
# 1  [area_label, mm, weekday, sum_rn, avg_ps, o3, ...
# 2  {'boosting_type': 'gbdt', 'class_weight': None...
# 3                                           0.901925
# 4                                           1.601719
# 5                                            1.26559
# 6                                           0.398844
# 7                                           0.473589

# %%
# print(list(result_frm.loc[[1],12]))
# print(list(result_frm.loc[[1],14]))

# %%
svr.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 3,
#  'epsilon': 0.1,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X_data, i) for i in range(X_data.shape[1])]
vif["features"] = X_data.columns
vif = vif.sort_values("VIF Factor").reset_index(drop=True)
vif
# Out:
#     VIF Factor       features
# 0     1.049547      heat_wave
# 1     1.073137      cold_wave
# 2     1.226691         sum_rn
# 3     1.418310     min_max_ps
# 4     2.524308      total_pop
# 5     3.261508        weekday
# 6     4.778337     area_label
# 7     5.059864        pm10_7b
# 8     5.308240             mm
# 9     8.313456             o3
# 10   22.405917      diff_temp
# 11   29.273804       diff_hum
# 12   46.388713  elderly_ratio
# 13  201.728167         avg_ps
# 14  377.052543        avg_age

# %%
vif['features']
# Out:
# 0         heat_wave
# 1         cold_wave
# 2            sum_rn
# 3        min_max_ps
# 4         total_pop
# 5           weekday
# 6        area_label
# 7           pm10_7b
# 8                mm
# 9                o3
# 10        diff_temp
# 11         diff_hum
# 12    elderly_ratio
# 13           avg_ps
# 14          avg_age
# Name: features, dtype: object

# %%
# from sklearn.linear_model import Ridge, Lasso, ElasticNet

# %%
# ridge = Ridge(alpha = 1)
# ridge.fit(train_poly, y_train)

# regression_model_predict(ridge, train_poly, test_poly, y_train, y_test, isFlag = True )

# print(ridge.score(train_poly, y_train))
# print(ridge.score(test_poly, y_test))

# %%
# las = Lasso(alpha = 1)
# las.fit(train_poly, y_train)

# regression_model_predict(las, train_poly, test_poly, y_train, y_test, isFlag = True )

# print(las.score(train_poly, y_train))
# print(las.score(test_poly, y_test))

# %%
# ela = ElasticNet(alpha = 0.1)
# ela.fit(train_poly, y_train)

# regression_model_predict(ela, train_poly, test_poly, y_train, y_test, isFlag = True )

# print(ela.score(train_poly, y_train))
# print(ela.score(test_poly, y_test))

# %%
#딥러닝

# %%
X_data
# Out:
#        area_label  mm  weekday    sum_rn       avg_ps        o3  total_pop  \
# 0               0   1        6  0.173611  1023.886667  0.027750     762617
# 1               1   1        6  0.037736  1024.875000  0.023165    5928150
# 2               2   1        6  0.065789  1022.950000  0.027277    1644251
# 3               3   1        6  0.721053  1023.268000  0.027274    1342455
# 4               4   1        6  0.700000  1025.250000  0.027300     738784
# ...           ...  ..      ...       ...          ...       ...        ...
# 24832          11  12        3  1.608108  1031.053846  0.035985     955115
# 24833          12  12        3  0.967742  1031.300000  0.028738     939456
# 24834          13  12        3  0.971429  1030.792308  0.044719     310967
# 24835          14  12        3  0.196970  1031.513333  0.024484    1023210
# 24836          15  12        3  0.096154  1030.850000  0.018966     785056
#
#        elderly_ratio  avg_age  min_max_ps  heat_wave  cold_wave  diff_hum  \
# 0          18.053361     42.4    6.340000          0          0      65.0
# 1          10.649039     37.7    5.500000          0          0      27.0
# 2          15.076105     40.5    5.200000          0          0      47.0
# 3          19.248690     43.2    5.688000          0          0      70.0
# 4          11.037868     37.6    4.100000          0          0      15.0
# ...              ...      ...         ...        ...        ...       ...
# 24832      24.847060     45.9    6.892308          0          0      65.0
# 24833      21.104873     44.2    7.014286          0          0      50.0
# 24834      16.470236     41.5    7.523077          0          0      33.0
# 24835      19.459055     43.1    6.800000          0          0      55.0
# 24836      17.517604     42.7    7.050000          0          0      55.0
#
#        diff_temp    pm10_7b
# 0           12.3  30.158333
# 1            7.9  28.537404
# 2            9.9  26.719907
# 3           12.0  25.336806
# 4            3.9  18.958333
# ...          ...        ...
# 24832       12.3  46.708333
# 24833       10.0  72.548882
# 24834        4.9  56.156250
# 24835        9.0  79.543252
# 24836       10.1  74.573958
#
# [24837 rows x 15 columns]

# %%
y_data
# Out:
#        frequency
# 0            3.0
# 1            5.0
# 2            1.0
# 3            1.0
# 4            2.0
# ...          ...
# 24832        3.0
# 24833        0.0
# 24834        0.0
# 24835        0.0
# 24836        0.0
#
# [24837 rows x 1 columns]

# %%
scaler = MinMaxScaler()
X_norm = scaler.fit_transform(X_data)

# %%
y_data['frequency']
# Out:
# 0        3.0
# 1        5.0
# 2        1.0
# 3        1.0
# 4        2.0
#         ...
# 24832    3.0
# 24833    0.0
# 24834    0.0
# 24835    0.0
# 24836    0.0
# Name: frequency, Length: 24837, dtype: float64

# %%
numpY = np.empty((24837, 1))
for i in range(24837):
    numpY[i] = y_data['frequency'][i]

# %%
X_norm.shape
# Out:
# (24837, 15)

# %%
numpY.shape
# Out:
# (24837, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_norm, 
                                                    numpY,
                                                   test_size = .2,
                                                    shuffle=True,
                                                   random_state = 1)

# %%
from tensorflow.keras import layers

# %%
def R_squared(y, y_pred):
    residual = tf.reduce_sum(tf.square(tf.subtract(y, y_pred)))
    total = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))
    r2 = tf.subtract(1.0, tf.divide(residual, total))
    return r2

# %%
# tf.random.set_seed(1)

model = tf.keras.Sequential()

#입력 8개로부터 전달받는 12개 노드의 layer 생성
model.add(layers.Dense(64, input_shape=(15,)))  
model.add(layers.Activation('relu'))  

model.add(layers.Dense(32))         
model.add(layers.Activation('relu'))

# model.add(layers.Dense(16))         
# model.add(layers.Activation('relu'))

#회귀모형(regression) 구축을 위해서 linear 활성함수 사용
model.add(layers.Dense(1))
model.add(layers.Activation('linear')) 

# 모델 구축하기
model.compile(
        loss='mse',         # mean_squared_error(평균제곱오차)의 alias
        optimizer='adam',   # 최적화 기법 중 하나
        metrics=[tf.keras.metrics.RootMeanSquaredError(), R_squared])    # 실험 후 관찰하고 싶은 metric 들을 나열함.

# %%
'''
10개에 한 번씩 업데이터 실행
0:미출력, 1:진행상황출력, 2:에포크당 출력
'''
hist = model.fit(
    X_train, y_train,
    batch_size=10,    
    epochs=100,       
    validation_split=0.2,  
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=15)],  
    verbose=2) 

# 테스트 데이터 입력
scores = model.evaluate(X_test, y_test)
print('test_loss: ', scores[0])
print('test_rmse: ', scores[1])
print('test_r2: ', scores[2])

# 모델 저장
model.save("dnn_weather_hospital10.h5")
# Out:
# Epoch 1/100
# 2022-08-03 15:40:08.727844: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-08-03 15:40:17.078945: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1590/1590 - 10s - loss: 1.7016 - root_mean_squared_error: 1.3044 - R_squared: 0.1230 - val_loss: 1.5200 - val_root_mean_squared_error: 1.2329 - val_R_squared: 0.0779 - 10s/epoch - 6ms/step
# Epoch 2/100
# 1590/1590 - 7s - loss: 1.5914 - root_mean_squared_error: 1.2615 - R_squared: 0.1338 - val_loss: 1.4921 - val_root_mean_squared_error: 1.2215 - val_R_squared: 0.1183 - 7s/epoch - 4ms/step
# Epoch 3/100
# 1590/1590 - 7s - loss: 1.5797 - root_mean_squared_error: 1.2569 - R_squared: 0.1537 - val_loss: 1.5631 - val_root_mean_squared_error: 1.2502 - val_R_squared: -5.5593e-03 - 7s/epoch - 4ms/step
# Epoch 4/100
# 1590/1590 - 7s - loss: 1.5652 - root_mean_squared_error: 1.2511 - R_squared: 0.1509 - val_loss: 1.5541 - val_root_mean_squared_error: 1.2466 - val_R_squared: 1.1447e-05 - 7s/epoch - 4ms/step
# Epoch 5/100
# 1590/1590 - 7s - loss: 1.5593 - root_mean_squared_error: 1.2487 - R_squared: 0.1749 - val_loss: 1.4827 - val_root_mean_squared_error: 1.2177 - val_R_squared: 0.1305 - 7s/epoch - 4ms/step
# Epoch 6/100
# 1590/1590 - 7s - loss: 1.5531 - root_mean_squared_error: 1.2462 - R_squared: 0.1780 - val_loss: 1.5279 - val_root_mean_squared_error: 1.2361 - val_R_squared: 0.0387 - 7s/epoch - 4ms/step
# Epoch 7/100
# 1590/1590 - 7s - loss: 1.5543 - root_mean_squared_error: 1.2467 - R_squared: 0.1739 - val_loss: 1.4678 - val_root_mean_squared_error: 1.2115 - val_R_squared: 0.1685 - 7s/epoch - 5ms/step
# Epoch 8/100
# 1590/1590 - 7s - loss: 1.5441 - root_mean_squared_error: 1.2426 - R_squared: 0.1801 - val_loss: 1.4828 - val_root_mean_squared_error: 1.2177 - val_R_squared: 0.1355 - 7s/epoch - 4ms/step
# Epoch 9/100
# 1590/1590 - 7s - loss: 1.5401 - root_mean_squared_error: 1.2410 - R_squared: 0.1708 - val_loss: 1.4735 - val_root_mean_squared_error: 1.2139 - val_R_squared: 0.1353 - 7s/epoch - 4ms/step
# Epoch 10/100
# 1590/1590 - 7s - loss: 1.5421 - root_mean_squared_error: 1.2418 - R_squared: 0.1637 - val_loss: 1.4638 - val_root_mean_squared_error: 1.2099 - val_R_squared: 0.1304 - 7s/epoch - 5ms/step
# Epoch 11/100
# 1590/1590 - 7s - loss: 1.5413 - root_mean_squared_error: 1.2415 - R_squared: 0.1875 - val_loss: 1.4761 - val_root_mean_squared_error: 1.2149 - val_R_squared: 0.1954 - 7s/epoch - 5ms/step
# Epoch 12/100
# 1590/1590 - 7s - loss: 1.5460 - root_mean_squared_error: 1.2434 - R_squared: 0.1750 - val_loss: 1.4617 - val_root_mean_squared_error: 1.2090 - val_R_squared: 0.1531 - 7s/epoch - 5ms/step
# Epoch 13/100
# 1590/1590 - 7s - loss: 1.5407 - root_mean_squared_error: 1.2412 - R_squared: 0.1739 - val_loss: 1.4595 - val_root_mean_squared_error: 1.2081 - val_R_squared: 0.1678 - 7s/epoch - 4ms/step
# Epoch 14/100
# 1590/1590 - 7s - loss: 1.5412 - root_mean_squared_error: 1.2414 - R_squared: -inf - val_loss: 1.4577 - val_root_mean_squared_error: 1.2074 - val_R_squared: 0.1635 - 7s/epoch - 4ms/step
# Epoch 15/100
# 1590/1590 - 7s - loss: 1.5390 - root_mean_squared_error: 1.2406 - R_squared: 0.1795 - val_loss: 1.4701 - val_root_mean_squared_error: 1.2125 - val_R_squared: 0.1140 - 7s/epoch - 4ms/step
# Epoch 16/100
# 1590/1590 - 7s - loss: 1.5302 - root_mean_squared_error: 1.2370 - R_squared: 0.1842 - val_loss: 1.4594 - val_root_mean_squared_error: 1.2081 - val_R_squared: 0.1740 - 7s/epoch - 5ms/step
# Epoch 17/100
# 1590/1590 - 7s - loss: 1.5322 - root_mean_squared_error: 1.2378 - R_squared: 0.1740 - val_loss: 1.4950 - val_root_mean_squared_error: 1.2227 - val_R_squared: 0.0634 - 7s/epoch - 5ms/step
# Epoch 18/100
# 1590/1590 - 7s - loss: 1.5316 - root_mean_squared_error: 1.2376 - R_squared: 0.2040 - val_loss: 1.4872 - val_root_mean_squared_error: 1.2195 - val_R_squared: 0.0902 - 7s/epoch - 5ms/step
# Epoch 19/100
# 1590/1590 - 7s - loss: 1.5333 - root_mean_squared_error: 1.2383 - R_squared: -inf - val_loss: 1.4557 - val_root_mean_squared_error: 1.2065 - val_R_squared: 0.1675 - 7s/epoch - 5ms/step
# Epoch 20/100
# 1590/1590 - 7s - loss: 1.5291 - root_mean_squared_error: 1.2366 - R_squared: 0.1837 - val_loss: 1.4760 - val_root_mean_squared_error: 1.2149 - val_R_squared: 0.0995 - 7s/epoch - 5ms/step
# Epoch 21/100
# 1590/1590 - 7s - loss: 1.5258 - root_mean_squared_error: 1.2352 - R_squared: 0.1861 - val_loss: 1.4627 - val_root_mean_squared_error: 1.2094 - val_R_squared: 0.1500 - 7s/epoch - 5ms/step
# Epoch 22/100
# 1590/1590 - 7s - loss: 1.5290 - root_mean_squared_error: 1.2365 - R_squared: -inf - val_loss: 1.4558 - val_root_mean_squared_error: 1.2066 - val_R_squared: 0.1382 - 7s/epoch - 4ms/step
# Epoch 23/100
# 1590/1590 - 7s - loss: 1.5244 - root_mean_squared_error: 1.2347 - R_squared: 0.1951 - val_loss: 1.4611 - val_root_mean_squared_error: 1.2088 - val_R_squared: 0.1489 - 7s/epoch - 5ms/step
# Epoch 24/100
# 1590/1590 - 7s - loss: 1.5260 - root_mean_squared_error: 1.2353 - R_squared: 0.1697 - val_loss: 1.4698 - val_root_mean_squared_error: 1.2123 - val_R_squared: 0.1178 - 7s/epoch - 5ms/step
# Epoch 25/100
# 1590/1590 - 7s - loss: 1.5256 - root_mean_squared_error: 1.2352 - R_squared: 0.1762 - val_loss: 1.4623 - val_root_mean_squared_error: 1.2093 - val_R_squared: 0.1624 - 7s/epoch - 5ms/step
# Epoch 26/100
# 1590/1590 - 7s - loss: 1.5235 - root_mean_squared_error: 1.2343 - R_squared: 0.1925 - val_loss: 1.4760 - val_root_mean_squared_error: 1.2149 - val_R_squared: 0.0904 - 7s/epoch - 5ms/step
# Epoch 27/100
# 1590/1590 - 7s - loss: 1.5189 - root_mean_squared_error: 1.2324 - R_squared: 0.1794 - val_loss: 1.4597 - val_root_mean_squared_error: 1.2082 - val_R_squared: 0.1588 - 7s/epoch - 5ms/step
# Epoch 28/100
# 1590/1590 - 7s - loss: 1.5195 - root_mean_squared_error: 1.2327 - R_squared: 0.1848 - val_loss: 1.4681 - val_root_mean_squared_error: 1.2116 - val_R_squared: 0.0981 - 7s/epoch - 5ms/step
# Epoch 29/100
# 1590/1590 - 7s - loss: 1.5184 - root_mean_squared_error: 1.2322 - R_squared: 0.1585 - val_loss: 1.4596 - val_root_mean_squared_error: 1.2081 - val_R_squared: 0.1480 - 7s/epoch - 5ms/step
# Epoch 30/100
# 1590/1590 - 7s - loss: 1.5182 - root_mean_squared_error: 1.2322 - R_squared: 0.1799 - val_loss: 1.4575 - val_root_mean_squared_error: 1.2073 - val_R_squared: 0.1514 - 7s/epoch - 5ms/step
# Epoch 31/100
# 1590/1590 - 7s - loss: 1.5162 - root_mean_squared_error: 1.2313 - R_squared: 0.1881 - val_loss: 1.4572 - val_root_mean_squared_error: 1.2071 - val_R_squared: 0.1505 - 7s/epoch - 4ms/step
# Epoch 32/100
# 1590/1590 - 7s - loss: 1.5128 - root_mean_squared_error: 1.2300 - R_squared: 0.1937 - val_loss: 1.4979 - val_root_mean_squared_error: 1.2239 - val_R_squared: 0.0566 - 7s/epoch - 5ms/step
# Epoch 33/100
# 1590/1590 - 7s - loss: 1.5110 - root_mean_squared_error: 1.2292 - R_squared: 0.2086 - val_loss: 1.4796 - val_root_mean_squared_error: 1.2164 - val_R_squared: 0.0872 - 7s/epoch - 5ms/step
# Epoch 34/100
# 1590/1590 - 7s - loss: 1.5165 - root_mean_squared_error: 1.2315 - R_squared: 0.1621 - val_loss: 1.4662 - val_root_mean_squared_error: 1.2109 - val_R_squared: 0.1057 - 7s/epoch - 4ms/step
# 156/156 [==============================] - 1s 5ms/step - loss: 1.4930 - root_mean_squared_error: 1.2219 - R_squared: 0.3704
# test_loss:  1.4930026531219482
# test_rmse:  1.221884846687317
# test_r2:  0.3704363703727722

# %%
model.save('./dnn_model_0803')
# Out:
# 2022-08-03 15:45:13.905194: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ./dnn_model_0803/assets

# %%
# 관찰된 metric 값들을 확인함
for i in range(len(scores)):
    print("%s: %.3f" % (model.metrics_names[i], scores[i]))
# Out:
# loss: 1.493
# root_mean_squared_error: 1.222
# R_squared: 0.370

# %%
def adj_r2_score(y_true, y_pred, p=X_data.shape[1]): 
    return 1-(1-r2_score(y_true, y_pred)) * (len(y_true)-1) / (len(y_true) - p - 1)

# %%
adj_r2_score(y_test, y_pred)
# Out:
# 0.4379502462629534

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots(figsize=(15, 5))

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')   # 훈련데이터의 loss (즉, mse)
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss') # 검증데이터의 loss (즉, mse)

acc_ax.plot(hist.history['root_mean_squared_error'], 'b', label='train rmse')   # 훈련데이터의 mae
acc_ax.plot(hist.history['val_root_mean_squared_error'], 'g', label='val rmse') # 검증데이터의 mae

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('mean_squared_error')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
import matplotlib.pyplot as plt

# test data에 대한 예측값
y_pred = model.predict(X_test)

# 그림 가로, 세로 크기
plt.figure(figsize=(10,10))  

#test data의 실제 y값과 예측 y값을 입력 => y=x 그래프와 가까울수록 정확
plt.scatter(y_test, y_pred, label="test", s=3)  
# plt.title('test title')

# X축 이름
plt.xlabel('y_actual')   
# Y축 이름
plt.ylabel('y_predicted')

# 범례표시
plt.legend()

# X축 표시 범위, Y축 표시 범위 
plt.xlim((0,20))  
plt.ylim((0,20))  

plt.show()
# Out:
# 2022-08-03 15:45:58.480740: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
hospital2 = hospital[[
'population_tot', 'precipitation_duration_hr', 
    'low_temp', 'high_temp',
#     'avg_temp',
    'o3_ppm', 'season_digit', 
    'avg_wind_speed', 'day_nm_digit', 
    'snow_cover_cm', 
    'avg_age', 
    'region_digit',
    'fat_rate','high_blood_pressure_rate',
    'fine_dust_modified',
        'frequency_tot']]

X_data = hospital2.drop(['frequency_tot'], axis=1)
y_data = hospital2[['frequency_tot']]

# %%
X_data
# Out:
#        population_tot  precipitation_duration_hr   low_temp  high_temp  \
# 0             1535335                   1.154615  -6.607692   1.553846
# 1             1535335                   0.410000  -9.376923   0.876923
# 2             1535335                   2.115385  -9.261538   0.692308
# 3             1535335                   0.269231 -10.307692  -2.400000
# 4             1535335                   0.000000 -12.638462  -0.515385
# ...               ...                        ...        ...        ...
# 17531         1578933                   0.000000 -10.440000   5.180000
# 17532         1578933                   0.000000  -9.420000   2.480000
# 17533         1578933                   0.000000  -2.720000   5.940000
# 17534         1578933                   0.000000  -4.340000   7.700000
# 17535         1578933                   2.116000  -6.240000   1.420000
#
#        o3_ppm  season_digit  avg_wind_speed  day_nm_digit  snow_cover_cm  \
# 0      0.0184             3        2.115385             3       2.200000
# 1      0.0184             3        1.592308             1       2.246154
# 2      0.0184             3        2.038462             5       2.176923
# 3      0.0184             3        2.484615             6       2.076923
# 4      0.0184             3        1.853846             4       1.884615
# ...       ...           ...             ...           ...            ...
# 17531  0.0134             3        0.640000             2       0.000000
# 17532  0.0134             3        0.780000             3       0.000000
# 17533  0.0134             3        1.040000             1       0.000000
# 17534  0.0134             3        2.040000             5       0.000000
# 17535  0.0134             3        2.560000             6       0.400000
#
#        avg_age  region_digit  fat_rate  high_blood_pressure_rate  \
# 0         40.9             0      27.7                      26.3
# 1         40.9             0      27.7                      26.3
# 2         40.9             0      27.7                      26.3
# 3         40.9             0      27.7                      26.3
# 4         40.9             0      27.7                      26.3
# ...        ...           ...       ...                       ...
# 17531     40.8            15      27.5                      24.9
# 17532     40.8            15      27.5                      24.9
# 17533     40.8            15      27.5                      24.9
# 17534     40.8            15      27.5                      24.9
# 17535     40.8            15      27.5                      24.9
#
#        fine_dust_modified
# 0                   36.00
# 1                   54.25
# 2                   73.75
# 3                   62.75
# 4                   75.00
# ...                   ...
# 17531               21.00
# 17532               30.00
# 17533               43.00
# 17534               20.00
# 17535               27.00
#
# [17536 rows x 14 columns]

# %%
X_data
# Out:
#        area_label  mm  weekday    sum_rn       avg_ps        o3  total_pop  \
# 0               0   1        6  0.173611  1023.886667  0.027750     762617
# 1               1   1        6  0.037736  1024.875000  0.023165    5928150
# 2               2   1        6  0.065789  1022.950000  0.027277    1644251
# 3               3   1        6  0.721053  1023.268000  0.027274    1342455
# 4               4   1        6  0.700000  1025.250000  0.027300     738784
# ...           ...  ..      ...       ...          ...       ...        ...
# 24832          11  12        3  1.608108  1031.053846  0.035985     955115
# 24833          12  12        3  0.967742  1031.300000  0.028738     939456
# 24834          13  12        3  0.971429  1030.792308  0.044719     310967
# 24835          14  12        3  0.196970  1031.513333  0.024484    1023210
# 24836          15  12        3  0.096154  1030.850000  0.018966     785056
#
#        elderly_ratio  avg_age  min_max_ps  heat_wave  cold_wave  diff_hum  \
# 0          18.053361     42.4    6.340000          0          0      65.0
# 1          10.649039     37.7    5.500000          0          0      27.0
# 2          15.076105     40.5    5.200000          0          0      47.0
# 3          19.248690     43.2    5.688000          0          0      70.0
# 4          11.037868     37.6    4.100000          0          0      15.0
# ...              ...      ...         ...        ...        ...       ...
# 24832      24.847060     45.9    6.892308          0          0      65.0
# 24833      21.104873     44.2    7.014286          0          0      50.0
# 24834      16.470236     41.5    7.523077          0          0      33.0
# 24835      19.459055     43.1    6.800000          0          0      55.0
# 24836      17.517604     42.7    7.050000          0          0      55.0
#
#        diff_temp    pm10_7b
# 0           12.3  30.158333
# 1            7.9  28.537404
# 2            9.9  26.719907
# 3           12.0  25.336806
# 4            3.9  18.958333
# ...          ...        ...
# 24832       12.3  46.708333
# 24833       10.0  72.548882
# 24834        4.9  56.156250
# 24835        9.0  79.543252
# 24836       10.1  74.573958
#
# [24837 rows x 15 columns]

# %%
scaler = MinMaxScaler()
X_norm = scaler.fit_transform(X_data)
numpY = np.empty((24837, 1))
for i in range(24837):
    numpY[i] = y_data['frequency'][i]
    
X_train, X_test, y_train, y_test = train_test_split(X_norm, 
                                                    numpY,
                                                   test_size = .2,
                                                    shuffle=True,
                                                   random_state = 1)

# %%
# 필요모듈
# from numpy import loadtxt
from tensorflow.python.keras.models import load_model

# 모델 불러오기
loaded_model = load_model("dnn_weather_hospital10.h5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [819], in <cell line: 6>()
#       3 from tensorflow.python.keras.models import load_model
#       5 # 모델 불러오기
# ----> 6 loaded_model = load_model("dnn_weather_hospital10.h5")
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/saving/save.py:201, in load_model(filepath, custom_objects, compile, options)
#     198 with load_context.load_context(options):
#     199   if (h5py is not None and
#     200       (isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 201     return hdf5_format.load_model_from_hdf5(filepath, custom_objects,
#     202                                             compile)
#     204   filepath = path_to_string(filepath)
#     205   if isinstance(filepath, str):
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/saving/hdf5_format.py:198, in load_model_from_hdf5(filepath, custom_objects, compile)
#     195 training_config = json_utils.decode(training_config)
#     197 # Compile model.
# --> 198 model.compile(**saving_utils.compile_args_from_training_config(
#     199     training_config, custom_objects), from_serialized=True)
#     200 saving_utils.try_build_compiled_arguments(model)
#     202 # Set optimizer weights.
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:219, in compile_args_from_training_config(training_config, custom_objects)
#     217 metrics_config = training_config.get('metrics', None)
#     218 if metrics_config is not None:
# --> 219   metrics = _deserialize_nested_config(_deserialize_metric, metrics_config)
#     221 # Recover weighted metrics.
#     222 weighted_metrics = None
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:261, in _deserialize_nested_config(deserialize_fn, config)
#     256   return {
#     257       k: _deserialize_nested_config(deserialize_fn, v)
#     258       for k, v in config.items()
#     259   }
#     260 elif isinstance(config, (tuple, list)):
# --> 261   return [_deserialize_nested_config(deserialize_fn, obj) for obj in config]
#     263 raise ValueError('Saved configuration not understood.')
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:261, in <listcomp>(.0)
#     256   return {
#     257       k: _deserialize_nested_config(deserialize_fn, v)
#     258       for k, v in config.items()
#     259   }
#     260 elif isinstance(config, (tuple, list)):
# --> 261   return [_deserialize_nested_config(deserialize_fn, obj) for obj in config]
#     263 raise ValueError('Saved configuration not understood.')
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:261, in _deserialize_nested_config(deserialize_fn, config)
#     256   return {
#     257       k: _deserialize_nested_config(deserialize_fn, v)
#     258       for k, v in config.items()
#     259   }
#     260 elif isinstance(config, (tuple, list)):
# --> 261   return [_deserialize_nested_config(deserialize_fn, obj) for obj in config]
#     263 raise ValueError('Saved configuration not understood.')
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:261, in <listcomp>(.0)
#     256   return {
#     257       k: _deserialize_nested_config(deserialize_fn, v)
#     258       for k, v in config.items()
#     259   }
#     260 elif isinstance(config, (tuple, list)):
# --> 261   return [_deserialize_nested_config(deserialize_fn, obj) for obj in config]
#     263 raise ValueError('Saved configuration not understood.')
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:254, in _deserialize_nested_config(deserialize_fn, config)
#     252   return None
#     253 if _is_single_object(config):
# --> 254   return deserialize_fn(config)
#     255 elif isinstance(config, dict):
#     256   return {
#     257       k: _deserialize_nested_config(deserialize_fn, v)
#     258       for k, v in config.items()
#     259   }
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:284, in _deserialize_metric(metric_config)
#     280 if metric_config in ['accuracy', 'acc', 'crossentropy', 'ce']:
#     281   # Do not deserialize accuracy and cross-entropy strings as we have special
#     282   # case handling for these in compile, based on model output shape.
#     283   return metric_config
# --> 284 return metrics_module.deserialize(metric_config)
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/metrics.py:3650, in deserialize(config, custom_objects)
#    3638 @keras_export('keras.metrics.deserialize')
#    3639 def deserialize(config, custom_objects=None):
#    3640   """Deserializes a serialized metric class/function instance.
#    3641
#    3642   Args:
#    (...)
#    3648       A Keras `Metric` instance or a metric function.
#    3649   """
# -> 3650   return deserialize_keras_object(
#    3651       config,
#    3652       module_objects=globals(),
#    3653       custom_objects=custom_objects,
#    3654       printable_module_name='metric function')
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/utils/generic_utils.py:681, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     679   else:
#     680     with CustomObjectScope(custom_objects):
# --> 681       deserialized_obj = cls.from_config(cls_config)
#     682 else:
#     683   # Then `cls` may be a function returning a class.
#     684   # in this case by convention `config` holds
#     685   # the kwargs of the function.
#     686   custom_objects = custom_objects or {}
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/metrics.py:698, in MeanMetricWrapper.from_config(cls, config)
#     696 fn = config.pop('fn', None)
#     697 if cls is MeanMetricWrapper:
# --> 698   return cls(get(fn), **config)
#     699 return super(MeanMetricWrapper, cls).from_config(config)
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/metrics.py:3694, in get(identifier)
#    3692   return deserialize(identifier)
#    3693 elif isinstance(identifier, str):
# -> 3694   return deserialize(str(identifier))
#    3695 elif callable(identifier):
#    3696   return identifier
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/metrics.py:3650, in deserialize(config, custom_objects)
#    3638 @keras_export('keras.metrics.deserialize')
#    3639 def deserialize(config, custom_objects=None):
#    3640   """Deserializes a serialized metric class/function instance.
#    3641
#    3642   Args:
#    (...)
#    3648       A Keras `Metric` instance or a metric function.
#    3649   """
# -> 3650   return deserialize_keras_object(
#    3651       config,
#    3652       module_objects=globals(),
#    3653       custom_objects=custom_objects,
#    3654       printable_module_name='metric function')
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/tensorflow/python/keras/utils/generic_utils.py:704, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     702   obj = module_objects.get(object_name)
#     703   if obj is None:
# --> 704     raise ValueError(
#     705         'Unknown {}: {}. Please ensure this object is '
#     706         'passed to the `custom_objects` argument. See '
#     707         'https://www.tensorflow.org/guide/keras/save_and_serialize'
#     708         '#registering_the_custom_object for details.'
#     709         .format(printable_module_name, object_name))
#     711 # Classes passed by name are instantiated with no args, functions are
#     712 # returned as-is.
#     713 if tf_inspect.isclass(obj):
#
# ValueError: Unknown metric function: R_squared. Please ensure this object is passed to the `custom_objects` argument. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %%
model.summary()

score = model.evaluate(X_test, y_test)
print('test_loss: ', score[0])
print('test_rmse: ', score[1])
# print('test_r2_score: ', score[2])
print('test_adj_r2_score: ', adj_r2_score(y_test, y_pred))
# Out:
# Model: "sequential_47"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_172 (Dense)           (None, 64)                960
#
#  activation_172 (Activation)  (None, 64)               0
#
#  dense_173 (Dense)           (None, 32)                2080
#
#  activation_173 (Activation)  (None, 32)               0
#
#  dense_174 (Dense)           (None, 1)                 33
#
#  activation_174 (Activation)  (None, 1)                0
#
# =================================================================
# Total params: 3,073
# Trainable params: 3,073
# Non-trainable params: 0
# _________________________________________________________________
# 110/110 [==============================] - 0s 4ms/step - loss: 3.1754 - root_mean_squared_error: 1.7820 - R_squared: 0.5200
# test_loss:  3.1753838062286377
# test_rmse:  1.7819607257843018
# test_r2_score:  0.5199968814849854
# test_adj_r2_score:  0.586393157698841

# %%
def R_squared(y, y_pred):
    residual = tf.reduce_sum(tf.square(tf.subtract(y, y_pred)))
    total = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))
    r2 = tf.subtract(1.0, tf.divide(residual, total))
    return r2

# %%
R_squared(y_test, y_pred)
# Out:
# <tf.Tensor: shape=(), dtype=float64, numpy=0.5864430701340259>

# %%
veri_data = pd.read_csv('./test_data.csv', encoding='utf-8')

# %%
veri_data.drop('Unnamed: 0', axis=1, inplace=True)
veri_data
# Out:
#         yyyymmdd area  frequency_m  frequency_f
# 0     2015-01-01   강원            4            2
# 1     2015-01-01   경기            4            6
# 2     2015-01-01   경남            6            1
# 3     2015-01-01   경북            5            3
# 4     2015-01-01   광주            2            4
# ...          ...  ...          ...          ...
# 6200  2015-12-31   전남            0            3
# 6201  2015-12-31   전북            1            0
# 6202  2015-12-31   제주            0            0
# 6203  2015-12-31   충남            0            0
# 6204  2015-12-31   충북            1            0
#
# [6205 rows x 4 columns]

# %%
y_test
# Out:
# array([[4.],
#        [0.],
#        [2.],
#        ...,
#        [2.],
#        [1.],
#        [2.]])

# %%
veri_data['frequency_tot'] = veri_data['frequency_f'] + veri_data['frequency_m']
veri_data
# Out:
#         yyyymmdd area  frequency_m  frequency_f  frequency_tot
# 0     2015-01-01   강원            4            2              6
# 1     2015-01-01   경기            4            6             10
# 2     2015-01-01   경남            6            1              7
# 3     2015-01-01   경북            5            3              8
# 4     2015-01-01   광주            2            4              6
# ...          ...  ...          ...          ...            ...
# 6200  2015-12-31   전남            0            3              3
# 6201  2015-12-31   전북            1            0              1
# 6202  2015-12-31   제주            0            0              0
# 6203  2015-12-31   충남            0            0              0
# 6204  2015-12-31   충북            1            0              1
#
# [6205 rows x 5 columns]

# %%
veri_test = veri_data['frequency_tot']

# %%
y_data
# Out:
#        frequency_tot
# 0                  6
# 1                  2
# 2                  0
# 3                  3
# 4                  3
# ...              ...
# 17531              2
# 17532              0
# 17533              1
# 17534              1
# 17535              1
#
# [17536 rows x 1 columns]

# %%
veri_test
# Out:
# 0        6
# 1       10
# 2        7
# 3        8
# 4        6
#         ..
# 6200     3
# 6201     1
# 6202     0
# 6203     0
# 6204     1
# Name: frequency_tot, Length: 6205, dtype: int64

# %%
numpV = np.empty((17536, 1))
for i in range(17536):
    numpV[i] = veri_test[i]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/pandas/core/indexes/range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: 6205 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [817], in <cell line: 2>()
#       1 numpV = np.empty((17536, 1))
#       2 for i in range(17536):
# ----> 3     numpV[i] = veri_test[i]
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/miniforge3/envs/tens2/lib/python3.9/site-packages/pandas/core/indexes/range.py:387, in RangeIndex.get_loc(self, key, method, tolerance)
#     385         return self._range.index(new_key)
#     386     except ValueError as err:
# --> 387         raise KeyError(key) from err
#     388 self._check_indexing_error(key)
#     389 raise KeyError(key)
#
# KeyError: 6205

# %%
y_data
# Out:
#        frequency_tot
# 0                  6
# 1                  2
# 2                  0
# 3                  3
# 4                  3
# ...              ...
# 17531              2
# 17532              0
# 17533              1
# 17534              1
# 17535              1
#
# [17536 rows x 1 columns]

# %%
X_data
# Out:
#        population_tot  precipitation_duration_hr   low_temp  high_temp  \
# 0             1535335                   1.154615  -6.607692   1.553846
# 1             1535335                   0.410000  -9.376923   0.876923
# 2             1535335                   2.115385  -9.261538   0.692308
# 3             1535335                   0.269231 -10.307692  -2.400000
# 4             1535335                   0.000000 -12.638462  -0.515385
# ...               ...                        ...        ...        ...
# 17531         1578933                   0.000000 -10.440000   5.180000
# 17532         1578933                   0.000000  -9.420000   2.480000
# 17533         1578933                   0.000000  -2.720000   5.940000
# 17534         1578933                   0.000000  -4.340000   7.700000
# 17535         1578933                   2.116000  -6.240000   1.420000
#
#        o3_ppm  season_digit  avg_wind_speed  day_nm_digit  snow_cover_cm  \
# 0      0.0184             3        2.115385             3       2.200000
# 1      0.0184             3        1.592308             1       2.246154
# 2      0.0184             3        2.038462             5       2.176923
# 3      0.0184             3        2.484615             6       2.076923
# 4      0.0184             3        1.853846             4       1.884615
# ...       ...           ...             ...           ...            ...
# 17531  0.0134             3        0.640000             2       0.000000
# 17532  0.0134             3        0.780000             3       0.000000
# 17533  0.0134             3        1.040000             1       0.000000
# 17534  0.0134             3        2.040000             5       0.000000
# 17535  0.0134             3        2.560000             6       0.400000
#
#        avg_age  fat_rate  high_blood_pressure_rate  fine_dust_modified
# 0         40.9      27.7                      26.3               36.00
# 1         40.9      27.7                      26.3               54.25
# 2         40.9      27.7                      26.3               73.75
# 3         40.9      27.7                      26.3               62.75
# 4         40.9      27.7                      26.3               75.00
# ...        ...       ...                       ...                 ...
# 17531     40.8      27.5                      24.9               21.00
# 17532     40.8      27.5                      24.9               30.00
# 17533     40.8      27.5                      24.9               43.00
# 17534     40.8      27.5                      24.9               20.00
# 17535     40.8      27.5                      24.9               27.00
#
# [17536 rows x 13 columns]

# %%
# 한값만 예측

# 정규화된 X 값
y_pred = model.predict(X_norm[[300]])
print('y_pred = ', y_pred)
print('y_test = ', y_test[300])

# 정규화 되지 않은 새로운 X값
X_new = [1535335, 1.154615, -6.607692, 1.553846, 0.0184, 3, 2.115385, 3, 2.200000, 40.9, 27.7, 26.3, 36.00]  
# X를 정규화
X_new_norm = scaler.transform([X_new])   

y_pred = model.predict(np.array(X_new_norm,))
print("y_pred = ", y_pred)
print("y_actual = ", y_test[0])
# Out:
# y_pred =  [[1.3925079]]
# y_test =  [3.]
# y_pred =  [[1.6688515]]
# y_actual =  [4.]
# /Users/ichanghun/miniforge3/envs/tens2/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Perform the intial fitting to get the LinearRegression object
from sklearn import linear_model
lm = linear_model.LinearRegression()
lm.fit(X_test, y_test)

mse_sum = 0
for sale, x in zip(y_test, X):
    prediction = lm.predict(x)
    mse_sum += (sale - prediction)**2
mse = mse_sum / len(sales)

print(mse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [492], in <cell line: 7>()
#       4 lm.fit(X_test, y_test)
#       6 mse_sum = 0
# ----> 7 for sale, x in zip(sales, X):
#       8     prediction = lm.predict(x)
#       9     mse_sum += (sale - prediction)**2
#
# NameError: name 'sales' is not defined
