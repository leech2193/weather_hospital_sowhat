# %% [markdown]
# # 2012-2015년 데이터로 모델 만들기(남자)

# %%
import pandas as pd
from itertools import *

# %%
dataset_male = pd.read_csv('./hospital_male_0725.csv', encoding='cp949')
male_df = dataset_male[['area','mm','weekday','frequency','total_pop','elderly_ratio','so2','pm10','o3','rhm_min_avg_dif','avg_ta','min_max_Ta','avg_ps','sum_rn']]
# fixed_df = dataset2[['area', 'mm', 'frequency','total_pop', 'elderly_ratio','so2','pm10','rhm_min_avg_dif','min_max_Ta','avg_ps']]
male_df
# Out:
#       area    mm  weekday  frequency  total_pop  elderly_ratio       so2  \
# 0       강원   1.0        6          3   772718.0      12.460044  0.012233
# 1       경기   1.0        6          4  6020446.0       7.432174  0.009216
# 2       경남   1.0        6          2  1665308.0       9.179443  0.008878
# 3       경북   1.0        6          6  1354649.0      12.336406  0.012868
# 4       광주   1.0        6          0   726529.0       7.679253  0.005629
# ...    ...   ...      ...        ...        ...            ...       ...
# 24832   전남  12.0        3          0   953881.0      16.198981  0.005860
# 24833   전북  12.0        3          1   930255.0      14.539347  0.004679
# 24834   제주  12.0        3          0   313428.0      11.063466  0.003344
# 24835   충남  12.0        3          0  1054439.0      13.477024  0.004875
# 24836   충북  12.0        3          1   798896.0      12.178056  0.005941
#
#             pm10        o3  rhm_min_avg_dif    avg_ta  min_max_Ta  \
# 0      86.279167  0.027750        23.088571 -4.226027    9.280556
# 1      91.567357  0.023165        25.065517 -3.962264    9.245283
# 2      59.554398  0.027277        19.133333  0.335897   10.074359
# 3      76.618056  0.027274        17.005263 -0.666667    9.628070
# 4      44.745833  0.027300        15.400000 -0.200000    6.500000
# ...          ...       ...              ...       ...         ...
# 24832  55.015673  0.035985        24.265854  4.156757    7.135135
# 24833  69.055014  0.028738        25.910417  1.583333    7.536667
# 24834  71.968750  0.044719        21.264516  5.128571    4.877143
# 24835  51.015625  0.024484        24.624837  1.912121    7.154545
# 24836  59.960417  0.018966        26.611765  0.230769    8.850000
#
#             avg_ps    sum_rn
# 0      1023.886667  0.173611
# 1      1024.875000  0.037736
# 2      1022.950000  0.065789
# 3      1023.268000  0.721053
# 4      1025.250000  0.700000
# ...            ...       ...
# 24832  1031.053846  1.608108
# 24833  1031.300000  0.967742
# 24834  1030.792308  0.971429
# 24835  1031.513333  0.196970
# 24836  1030.850000  0.096154
#
# [24837 rows x 14 columns]

# %%
male_data = male_df.sample(frac=0.9, random_state=786) 
male_data_unseen = male_df.drop(male_data.index) 

male_data.reset_index(drop=True, inplace=True) 
male_data_unseen.reset_index(drop=True, inplace=True) 

print('Data for Modeling: ' + str(male_data.shape)) 
print('Unseen Data For Predictions: ' + str(male_data_unseen.shape))
# Out:
# Data for Modeling: (22353, 14)
# Unseen Data For Predictions: (2484, 14)

# %% [markdown]
# ## 모델 환경 설정 (Settinf up Environment in PyCaret)
#
# - pycaret을 사용하기 전에 pycaret에 맞게 데이터를 설정
# - set_up() 함수를 사용
# - 기본적으로 data와 target을 입력

# %%
# 자동으로 데이터 유형 지정 
from pycaret.regression import *
s = setup(male_data, target = 'frequency', session_id=123)
# Out:
# <style type="text/css">
# #T_2a757_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2a757">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a757_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2a757_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a757_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a757_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2a757_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2a757_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2a757_row1_col1" class="data row1 col1" >frequency</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2a757_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2a757_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2a757_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_2a757_row3_col1" class="data row3 col1" >(22353, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2a757_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_2a757_row4_col1" class="data row4 col1" >(15647, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2a757_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_2a757_row5_col1" class="data row5 col1" >(6706, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2a757_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_2a757_row6_col1" class="data row6 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2a757_row7_col0" class="data row7 col0" >Categorical features</td>
#       <td id="T_2a757_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2a757_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_2a757_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2a757_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_2a757_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2a757_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_2a757_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2a757_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_2a757_row11_col1" class="data row11 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2a757_row12_col0" class="data row12 col0" >Maximum one-hot encoding</td>
#       <td id="T_2a757_row12_col1" class="data row12 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2a757_row13_col0" class="data row13 col0" >Encoding method</td>
#       <td id="T_2a757_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2a757_row14_col0" class="data row14 col0" >Low variance threshold</td>
#       <td id="T_2a757_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2a757_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_2a757_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2a757_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_2a757_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2a757_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_2a757_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2a757_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_2a757_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2a757_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_2a757_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2a757_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_2a757_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2a757_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2a757_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_2a757_row21_col1" class="data row21 col1" >7da6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### set_up(): pycaret을 사용하기 위한 data setting
#
# - session_id: random_state와 같은 개념으로 같은 결과가 나올 수 있게 seed를 고정
# - data: train 데이터 입력
# - target = target 변수 이름을 입력

# %% [markdown]
# ## 모델 생성 - 비교
#
# - 여러 모델을 적합하여 성능을 비교하는 단계
# - compare_models(): 다양한 모델 적합 후 성능 비교
#     - fold: cross_validation의 fold를 지정 (default = 10)
#     - sort: 정렬기준 지표 설정
#     - n_select: 상위 n개의 모델 결과만 출력

# %%
et_male = create_model('et')
# Out:
# <style type="text/css">
# #T_acafc_row10_col0, #T_acafc_row10_col1, #T_acafc_row10_col2, #T_acafc_row10_col3, #T_acafc_row10_col4, #T_acafc_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_acafc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_acafc_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_acafc_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_acafc_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_acafc_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_acafc_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_acafc_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acafc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_acafc_row0_col0" class="data row0 col0" >0.9247</td>
#       <td id="T_acafc_row0_col1" class="data row0 col1" >1.6771</td>
#       <td id="T_acafc_row0_col2" class="data row0 col2" >1.2950</td>
#       <td id="T_acafc_row0_col3" class="data row0 col3" >0.4036</td>
#       <td id="T_acafc_row0_col4" class="data row0 col4" >0.4941</td>
#       <td id="T_acafc_row0_col5" class="data row0 col5" >0.4616</td>
#     </tr>
#     <tr>
#       <th id="T_acafc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_acafc_row1_col0" class="data row1 col0" >0.9205</td>
#       <td id="T_acafc_row1_col1" class="data row1 col1" >1.6434</td>
#       <td id="T_acafc_row1_col2" class="data row1 col2" >1.2820</td>
#       <td id="T_acafc_row1_col3" class="data row1 col3" >0.4182</td>
#       <td id="T_acafc_row1_col4" class="data row1 col4" >0.4929</td>
#       <td id="T_acafc_row1_col5" class="data row1 col5" >0.4423</td>
#     </tr>
#     <tr>
#       <th id="T_acafc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_acafc_row2_col0" class="data row2 col0" >0.9041</td>
#       <td id="T_acafc_row2_col1" class="data row2 col1" >1.5281</td>
#       <td id="T_acafc_row2_col2" class="data row2 col2" >1.2361</td>
#       <td id="T_acafc_row2_col3" class="data row2 col3" >0.4630</td>
#       <td id="T_acafc_row2_col4" class="data row2 col4" >0.4869</td>
#       <td id="T_acafc_row2_col5" class="data row2 col5" >0.4323</td>
#     </tr>
#     <tr>
#       <th id="T_acafc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_acafc_row3_col0" class="data row3 col0" >0.9097</td>
#       <td id="T_acafc_row3_col1" class="data row3 col1" >1.6145</td>
#       <td id="T_acafc_row3_col2" class="data row3 col2" >1.2706</td>
#       <td id="T_acafc_row3_col3" class="data row3 col3" >0.4444</td>
#       <td id="T_acafc_row3_col4" class="data row3 col4" >0.4879</td>
#       <td id="T_acafc_row3_col5" class="data row3 col5" >0.4511</td>
#     </tr>
#     <tr>
#       <th id="T_acafc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_acafc_row4_col0" class="data row4 col0" >0.9149</td>
#       <td id="T_acafc_row4_col1" class="data row4 col1" >1.5236</td>
#       <td id="T_acafc_row4_col2" class="data row4 col2" >1.2343</td>
#       <td id="T_acafc_row4_col3" class="data row4 col3" >0.4479</td>
#       <td id="T_acafc_row4_col4" class="data row4 col4" >0.5006</td>
#       <td id="T_acafc_row4_col5" class="data row4 col5" >0.4389</td>
#     </tr>
#     <tr>
#       <th id="T_acafc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_acafc_row5_col0" class="data row5 col0" >0.8895</td>
#       <td id="T_acafc_row5_col1" class="data row5 col1" >1.5128</td>
#       <td id="T_acafc_row5_col2" class="data row5 col2" >1.2299</td>
#       <td id="T_acafc_row5_col3" class="data row5 col3" >0.4979</td>
#       <td id="T_acafc_row5_col4" class="data row5 col4" >0.4776</td>
#       <td id="T_acafc_row5_col5" class="data row5 col5" >0.4154</td>
#     </tr>
#     <tr>
#       <th id="T_acafc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_acafc_row6_col0" class="data row6 col0" >0.9158</td>
#       <td id="T_acafc_row6_col1" class="data row6 col1" >1.5689</td>
#       <td id="T_acafc_row6_col2" class="data row6 col2" >1.2526</td>
#       <td id="T_acafc_row6_col3" class="data row6 col3" >0.4568</td>
#       <td id="T_acafc_row6_col4" class="data row6 col4" >0.4984</td>
#       <td id="T_acafc_row6_col5" class="data row6 col5" >0.4419</td>
#     </tr>
#     <tr>
#       <th id="T_acafc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_acafc_row7_col0" class="data row7 col0" >0.9050</td>
#       <td id="T_acafc_row7_col1" class="data row7 col1" >1.5277</td>
#       <td id="T_acafc_row7_col2" class="data row7 col2" >1.2360</td>
#       <td id="T_acafc_row7_col3" class="data row7 col3" >0.4474</td>
#       <td id="T_acafc_row7_col4" class="data row7 col4" >0.4901</td>
#       <td id="T_acafc_row7_col5" class="data row7 col5" >0.4695</td>
#     </tr>
#     <tr>
#       <th id="T_acafc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_acafc_row8_col0" class="data row8 col0" >0.9706</td>
#       <td id="T_acafc_row8_col1" class="data row8 col1" >1.7580</td>
#       <td id="T_acafc_row8_col2" class="data row8 col2" >1.3259</td>
#       <td id="T_acafc_row8_col3" class="data row8 col3" >0.4072</td>
#       <td id="T_acafc_row8_col4" class="data row8 col4" >0.5130</td>
#       <td id="T_acafc_row8_col5" class="data row8 col5" >0.4833</td>
#     </tr>
#     <tr>
#       <th id="T_acafc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_acafc_row9_col0" class="data row9 col0" >0.8967</td>
#       <td id="T_acafc_row9_col1" class="data row9 col1" >1.5498</td>
#       <td id="T_acafc_row9_col2" class="data row9 col2" >1.2449</td>
#       <td id="T_acafc_row9_col3" class="data row9 col3" >0.4578</td>
#       <td id="T_acafc_row9_col4" class="data row9 col4" >0.4814</td>
#       <td id="T_acafc_row9_col5" class="data row9 col5" >0.4203</td>
#     </tr>
#     <tr>
#       <th id="T_acafc_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_acafc_row10_col0" class="data row10 col0" >0.9152</td>
#       <td id="T_acafc_row10_col1" class="data row10 col1" >1.5904</td>
#       <td id="T_acafc_row10_col2" class="data row10 col2" >1.2607</td>
#       <td id="T_acafc_row10_col3" class="data row10 col3" >0.4444</td>
#       <td id="T_acafc_row10_col4" class="data row10 col4" >0.4923</td>
#       <td id="T_acafc_row10_col5" class="data row10 col5" >0.4457</td>
#     </tr>
#     <tr>
#       <th id="T_acafc_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_acafc_row11_col0" class="data row11 col0" >0.0211</td>
#       <td id="T_acafc_row11_col1" class="data row11 col1" >0.0771</td>
#       <td id="T_acafc_row11_col2" class="data row11 col2" >0.0302</td>
#       <td id="T_acafc_row11_col3" class="data row11 col3" >0.0270</td>
#       <td id="T_acafc_row11_col4" class="data row11 col4" >0.0096</td>
#       <td id="T_acafc_row11_col5" class="data row11 col5" >0.0202</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# # 2012-2015년 데이터로 모델 만들기(여자)

# %%
dataset_female = pd.read_csv('./hospital_female_0725.csv', encoding='cp949')
female_df = dataset_female[['area','mm','weekday','frequency','total_pop','elderly_ratio','so2','pm10','o3','rhm_min_avg_dif','avg_ta','min_max_Ta','avg_ps','sum_rn']]
# fixed_df = dataset2[['area', 'mm', 'frequency','total_pop', 'elderly_ratio','so2','pm10','rhm_min_avg_dif','min_max_Ta','avg_ps']]
female_df
# Out:
#       area    mm  weekday  frequency  total_pop  elderly_ratio       so2  \
# 0       강원   1.0        6          3   762617.0      18.053361  0.012233
# 1       경기   1.0        6          5  5928150.0      10.649039  0.009216
# 2       경남   1.0        6          1  1644251.0      15.076105  0.008878
# 3       경북   1.0        6          1  1342455.0      19.248690  0.012868
# 4       광주   1.0        6          2   738784.0      11.037868  0.005629
# ...    ...   ...      ...        ...        ...            ...       ...
# 24832   전남  12.0        3          3   955115.0      24.847060  0.005860
# 24833   전북  12.0        3          0   939456.0      21.104873  0.004679
# 24834   제주  12.0        3          0   310967.0      16.470236  0.003344
# 24835   충남  12.0        3          0  1023210.0      19.459055  0.004875
# 24836   충북  12.0        3          0   785056.0      17.517604  0.005941
#
#             pm10        o3  rhm_min_avg_dif    avg_ta  min_max_Ta  \
# 0      86.279167  0.027750        23.088571 -4.226027    9.280556
# 1      91.567357  0.023165        25.065517 -3.962264    9.245283
# 2      59.554398  0.027277        19.133333  0.335897   10.074359
# 3      76.618056  0.027274        17.005263 -0.666667    9.628070
# 4      44.745833  0.027300        15.400000 -0.200000    6.500000
# ...          ...       ...              ...       ...         ...
# 24832  55.015673  0.035985        24.265854  4.156757    7.135135
# 24833  69.055014  0.028738        25.910417  1.583333    7.536667
# 24834  71.968750  0.044719        21.264516  5.128571    4.877143
# 24835  51.015625  0.024484        24.624837  1.912121    7.154545
# 24836  59.960417  0.018966        26.611765  0.230769    8.850000
#
#             avg_ps    sum_rn
# 0      1023.886667  0.173611
# 1      1024.875000  0.037736
# 2      1022.950000  0.065789
# 3      1023.268000  0.721053
# 4      1025.250000  0.700000
# ...            ...       ...
# 24832  1031.053846  1.608108
# 24833  1031.300000  0.967742
# 24834  1030.792308  0.971429
# 24835  1031.513333  0.196970
# 24836  1030.850000  0.096154
#
# [24837 rows x 14 columns]

# %%
female_data = female_df.sample(frac=0.9, random_state=786) 
female_data_unseen = female_df.drop(female_data.index) 

female_data.reset_index(drop=True, inplace=True) 
female_data_unseen.reset_index(drop=True, inplace=True) 

print('Data for Modeling: ' + str(female_data.shape)) 
print('Unseen Data For Predictions: ' + str(female_data_unseen.shape))
# Out:
# Data for Modeling: (22353, 14)
# Unseen Data For Predictions: (2484, 14)

# %%
# 자동으로 데이터 유형 지정 
from pycaret.regression import *
s = setup(female_data, target = 'frequency', session_id=123)
# Out:
# <style type="text/css">
# #T_fc074_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fc074">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc074_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fc074_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc074_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc074_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fc074_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc074_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fc074_row1_col1" class="data row1 col1" >frequency</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fc074_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_fc074_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fc074_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_fc074_row3_col1" class="data row3 col1" >(22353, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fc074_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_fc074_row4_col1" class="data row4 col1" >(15647, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fc074_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_fc074_row5_col1" class="data row5 col1" >(6706, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fc074_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_fc074_row6_col1" class="data row6 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fc074_row7_col0" class="data row7 col0" >Categorical features</td>
#       <td id="T_fc074_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fc074_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_fc074_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fc074_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_fc074_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fc074_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_fc074_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fc074_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_fc074_row11_col1" class="data row11 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fc074_row12_col0" class="data row12 col0" >Maximum one-hot encoding</td>
#       <td id="T_fc074_row12_col1" class="data row12 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fc074_row13_col0" class="data row13 col0" >Encoding method</td>
#       <td id="T_fc074_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fc074_row14_col0" class="data row14 col0" >Low variance threshold</td>
#       <td id="T_fc074_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fc074_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_fc074_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fc074_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_fc074_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fc074_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_fc074_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fc074_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_fc074_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fc074_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_fc074_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fc074_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_fc074_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fc074_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_fc074_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_fc074_row21_col1" class="data row21 col1" >b76f</td>
#     </tr>
#   </tbody>
# </table>

# %%
et_female = create_model('et')
# Out:
# <style type="text/css">
# #T_0677b_row10_col0, #T_0677b_row10_col1, #T_0677b_row10_col2, #T_0677b_row10_col3, #T_0677b_row10_col4, #T_0677b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0677b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0677b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0677b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0677b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0677b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0677b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0677b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0677b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0677b_row0_col0" class="data row0 col0" >0.8993</td>
#       <td id="T_0677b_row0_col1" class="data row0 col1" >1.4842</td>
#       <td id="T_0677b_row0_col2" class="data row0 col2" >1.2183</td>
#       <td id="T_0677b_row0_col3" class="data row0 col3" >0.4412</td>
#       <td id="T_0677b_row0_col4" class="data row0 col4" >0.4782</td>
#       <td id="T_0677b_row0_col5" class="data row0 col5" >0.4652</td>
#     </tr>
#     <tr>
#       <th id="T_0677b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0677b_row1_col0" class="data row1 col0" >0.9181</td>
#       <td id="T_0677b_row1_col1" class="data row1 col1" >1.5514</td>
#       <td id="T_0677b_row1_col2" class="data row1 col2" >1.2456</td>
#       <td id="T_0677b_row1_col3" class="data row1 col3" >0.4454</td>
#       <td id="T_0677b_row1_col4" class="data row1 col4" >0.4921</td>
#       <td id="T_0677b_row1_col5" class="data row1 col5" >0.4419</td>
#     </tr>
#     <tr>
#       <th id="T_0677b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0677b_row2_col0" class="data row2 col0" >0.9064</td>
#       <td id="T_0677b_row2_col1" class="data row2 col1" >1.5705</td>
#       <td id="T_0677b_row2_col2" class="data row2 col2" >1.2532</td>
#       <td id="T_0677b_row2_col3" class="data row2 col3" >0.4412</td>
#       <td id="T_0677b_row2_col4" class="data row2 col4" >0.4876</td>
#       <td id="T_0677b_row2_col5" class="data row2 col5" >0.4348</td>
#     </tr>
#     <tr>
#       <th id="T_0677b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0677b_row3_col0" class="data row3 col0" >0.8722</td>
#       <td id="T_0677b_row3_col1" class="data row3 col1" >1.5166</td>
#       <td id="T_0677b_row3_col2" class="data row3 col2" >1.2315</td>
#       <td id="T_0677b_row3_col3" class="data row3 col3" >0.4382</td>
#       <td id="T_0677b_row3_col4" class="data row3 col4" >0.4709</td>
#       <td id="T_0677b_row3_col5" class="data row3 col5" >0.4376</td>
#     </tr>
#     <tr>
#       <th id="T_0677b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0677b_row4_col0" class="data row4 col0" >0.9021</td>
#       <td id="T_0677b_row4_col1" class="data row4 col1" >1.5920</td>
#       <td id="T_0677b_row4_col2" class="data row4 col2" >1.2618</td>
#       <td id="T_0677b_row4_col3" class="data row4 col3" >0.4635</td>
#       <td id="T_0677b_row4_col4" class="data row4 col4" >0.4811</td>
#       <td id="T_0677b_row4_col5" class="data row4 col5" >0.4072</td>
#     </tr>
#     <tr>
#       <th id="T_0677b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0677b_row5_col0" class="data row5 col0" >0.9047</td>
#       <td id="T_0677b_row5_col1" class="data row5 col1" >1.5163</td>
#       <td id="T_0677b_row5_col2" class="data row5 col2" >1.2314</td>
#       <td id="T_0677b_row5_col3" class="data row5 col3" >0.4100</td>
#       <td id="T_0677b_row5_col4" class="data row5 col4" >0.4925</td>
#       <td id="T_0677b_row5_col5" class="data row5 col5" >0.4753</td>
#     </tr>
#     <tr>
#       <th id="T_0677b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0677b_row6_col0" class="data row6 col0" >0.9283</td>
#       <td id="T_0677b_row6_col1" class="data row6 col1" >1.6449</td>
#       <td id="T_0677b_row6_col2" class="data row6 col2" >1.2825</td>
#       <td id="T_0677b_row6_col3" class="data row6 col3" >0.4075</td>
#       <td id="T_0677b_row6_col4" class="data row6 col4" >0.5003</td>
#       <td id="T_0677b_row6_col5" class="data row6 col5" >0.4458</td>
#     </tr>
#     <tr>
#       <th id="T_0677b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0677b_row7_col0" class="data row7 col0" >0.8778</td>
#       <td id="T_0677b_row7_col1" class="data row7 col1" >1.4861</td>
#       <td id="T_0677b_row7_col2" class="data row7 col2" >1.2191</td>
#       <td id="T_0677b_row7_col3" class="data row7 col3" >0.4435</td>
#       <td id="T_0677b_row7_col4" class="data row7 col4" >0.4787</td>
#       <td id="T_0677b_row7_col5" class="data row7 col5" >0.4575</td>
#     </tr>
#     <tr>
#       <th id="T_0677b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0677b_row8_col0" class="data row8 col0" >0.9030</td>
#       <td id="T_0677b_row8_col1" class="data row8 col1" >1.5122</td>
#       <td id="T_0677b_row8_col2" class="data row8 col2" >1.2297</td>
#       <td id="T_0677b_row8_col3" class="data row8 col3" >0.4417</td>
#       <td id="T_0677b_row8_col4" class="data row8 col4" >0.4868</td>
#       <td id="T_0677b_row8_col5" class="data row8 col5" >0.4641</td>
#     </tr>
#     <tr>
#       <th id="T_0677b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0677b_row9_col0" class="data row9 col0" >0.9063</td>
#       <td id="T_0677b_row9_col1" class="data row9 col1" >1.5454</td>
#       <td id="T_0677b_row9_col2" class="data row9 col2" >1.2431</td>
#       <td id="T_0677b_row9_col3" class="data row9 col3" >0.4179</td>
#       <td id="T_0677b_row9_col4" class="data row9 col4" >0.4891</td>
#       <td id="T_0677b_row9_col5" class="data row9 col5" >0.4581</td>
#     </tr>
#     <tr>
#       <th id="T_0677b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0677b_row10_col0" class="data row10 col0" >0.9018</td>
#       <td id="T_0677b_row10_col1" class="data row10 col1" >1.5420</td>
#       <td id="T_0677b_row10_col2" class="data row10 col2" >1.2416</td>
#       <td id="T_0677b_row10_col3" class="data row10 col3" >0.4350</td>
#       <td id="T_0677b_row10_col4" class="data row10 col4" >0.4857</td>
#       <td id="T_0677b_row10_col5" class="data row10 col5" >0.4487</td>
#     </tr>
#     <tr>
#       <th id="T_0677b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0677b_row11_col0" class="data row11 col0" >0.0158</td>
#       <td id="T_0677b_row11_col1" class="data row11 col1" >0.0476</td>
#       <td id="T_0677b_row11_col2" class="data row11 col2" >0.0191</td>
#       <td id="T_0677b_row11_col3" class="data row11 col3" >0.0167</td>
#       <td id="T_0677b_row11_col4" class="data row11 col4" >0.0081</td>
#       <td id="T_0677b_row11_col5" class="data row11 col5" >0.0187</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# # 2016년 예측(남자)

# %%
test_male = pd.read_csv('./hospital_male_0726_test.csv', encoding='cp949') #이 csv 파일은 2016년 데이터까지 포함한 것
# dataset3.drop(columns=['Unnamed: 0'], inplace=True)
test_male = test_male[['area','yyyy','dd','mm','weekday','frequency','total_pop','elderly_ratio','so2','pm10','o3','rhm_min_avg_dif','avg_ta','min_max_Ta','avg_ps','sum_rn']]
test_male
# Out:
#       area  yyyy  dd  mm  weekday  frequency  total_pop  elderly_ratio  \
# 0       강원  2011   1  12        3        3.0     773278      12.405500
# 1       경기  2011   1  12        3        4.0    6015357       7.388123
# 2       경남  2011   1  12        3        2.0    1664755       9.147472
# 3       경북  2011   1  12        3        6.0    1355727      12.284700
# 4       광주  2011   1  12        3        0.0     725606       7.629485
# ...    ...   ...  ..  ..      ...        ...        ...            ...
# 31581   전남  2016  31  12        5        NaN     951889      16.677050
# 31582   전북  2016  31  12        5        NaN     927505      15.011563
# 31583   제주  2016  31  12        5        NaN     322545      11.278426
# 31584   충남  2016  31  12        5        NaN    1064765      13.768860
# 31585   충북  2016  31  12        5        NaN     803240      12.472486
#
#             so2       pm10        o3  rhm_min_avg_dif    avg_ta  min_max_Ta  \
# 0      0.003307  15.678261  0.027986        16.669545  1.281944    3.845070
# 1      0.002937  13.474891  0.024401        14.113793  5.360377    5.413208
# 2      0.002409  16.193461  0.027836         9.783333  6.394872    3.112821
# 3      0.003815  12.743785  0.027465        14.400000  4.429091    3.338182
# 4      0.002166   8.566667  0.021888        12.066667  6.240000    3.840000
# ...         ...        ...       ...              ...       ...         ...
# 31581  0.005431  34.282500  0.025507        21.753535  2.539189   10.937838
# 31582  0.003583  44.546347  0.021604        15.777778  1.012903    9.300000
# 31583  0.001490  24.247294  0.039094        22.135484  3.997143    7.931429
# 31584  0.002906  43.536458  0.019109        17.345000  2.663636    7.596970
# 31585  0.005038  50.466667  0.010403        17.330000 -1.018519    9.451852
#
#             avg_ps    sum_rn
# 0      1027.575000  3.038889
# 1      1025.875000  0.009434
# 2      1023.921429  1.789474
# 3      1026.137500  2.185965
# 4      1022.900000  3.200000
# ...            ...       ...
# 31581  1030.607692  0.000000
# 31582  1030.586667  0.000000
# 31583  1029.900000  0.000000
# 31584  1030.100000  0.045455
# 31585  1031.400000  0.000000
#
# [31586 rows x 16 columns]

# %%
test_male2 = test_male[test_male['yyyy'].astype(str).str.contains('2016')].reset_index(drop=True)#2016년만 추출
test_male2
# Out:
#      area  yyyy  dd  mm  weekday  frequency  total_pop  elderly_ratio  \
# 0      강원  2016   1   1        4        NaN     781185      14.022671
# 1      경기  2016   1   1        4        NaN    6306634       8.966558
# 2      경남  2016   1   1        4        NaN    1695187      10.962802
# 3      경북  2016   1   1        4        NaN    1356568      14.384461
# 4      광주  2016   1   1        4        NaN     729995       9.572120
# ...   ...   ...  ..  ..      ...        ...        ...            ...
# 6217   전남  2016  31  12        5        NaN     951889      16.677050
# 6218   전북  2016  31  12        5        NaN     927505      15.011563
# 6219   제주  2016  31  12        5        NaN     322545      11.278426
# 6220   충남  2016  31  12        5        NaN    1064765      13.768860
# 6221   충북  2016  31  12        5        NaN     803240      12.472486
#
#            so2       pm10        o3  rhm_min_avg_dif    avg_ta  min_max_Ta  \
# 0     0.005067  54.629545  0.024237        19.665950 -1.454167   10.104167
# 1     0.005282  79.033906  0.014370        20.108824 -0.091837   10.661702
# 2     0.004755  55.186508  0.029582        31.638889  0.815000   13.610000
# 3     0.006256  62.858333  0.033232        28.396296  0.371429   13.244643
# 4     0.002750  57.875000  0.025175        23.400000  1.300000   10.300000
# ...        ...        ...       ...              ...       ...         ...
# 6217  0.005431  34.282500  0.025507        21.753535  2.539189   10.937838
# 6218  0.003583  44.546347  0.021604        15.777778  1.012903    9.300000
# 6219  0.001490  24.247294  0.039094        22.135484  3.997143    7.931429
# 6220  0.002906  43.536458  0.019109        17.345000  2.663636    7.596970
# 6221  0.005038  50.466667  0.010403        17.330000 -1.018519    9.451852
#
#            avg_ps    sum_rn
# 0     1030.230000  0.000000
# 1     1031.633333  0.000000
# 2     1031.175000  0.000000
# 3     1030.309524  0.000000
# 4     1032.200000  0.000000
# ...           ...       ...
# 6217  1030.607692  0.000000
# 6218  1030.586667  0.000000
# 6219  1029.900000  0.000000
# 6220  1030.100000  0.045455
# 6221  1031.400000  0.000000
#
# [6222 rows x 16 columns]

# %%
test_male3 = test_male2.drop(columns=['frequency','yyyy','dd'])

# %%
final_model = finalize_model(et_male)
prediction_male = predict_model(final_model, data = test_male3)

# %%
prediction_male[['Label']]
# Out:
#       Label
# 0      0.66
# 1      4.45
# 2      2.22
# 3      2.36
# 4      0.85
# ...     ...
# 6217   1.46
# 6218   1.54
# 6219   0.57
# 6220   1.42
# 6221   0.96
#
# [6222 rows x 1 columns]

# %%
prediction_male['Label'] = prediction_male['Label'].round(0)
prediction_male[['Label']]
# Out:
#       Label
# 0       1.0
# 1       4.0
# 2       2.0
# 3       2.0
# 4       1.0
# ...     ...
# 6217    1.0
# 6218    2.0
# 6219    1.0
# 6220    1.0
# 6221    1.0
#
# [6222 rows x 1 columns]

# %% [markdown]
# # 2016년 예측(여자)

# %%
test_female = pd.read_csv('./hospital_female_0726_test.csv', encoding='cp949') #이 csv 파일은 2016년 데이터까지 포함한 것
# dataset3.drop(columns=['Unnamed: 0'], inplace=True)
test_female = test_female[['area','yyyy','dd','mm','weekday','frequency','total_pop','elderly_ratio','so2','pm10','o3','rhm_min_avg_dif','avg_ta','min_max_Ta','avg_ps','sum_rn']]
test_female
# Out:
#       area  yyyy  dd  mm  weekday  frequency  total_pop  elderly_ratio  \
# 0       강원  2011   1  12        3        3.0     763170      17.989439
# 1       경기  2011   1  12        3        5.0    5922058      10.605097
# 2       경남  2011   1  12        3        1.0    1644010      15.039264
# 3       경북  2011   1  12        3        1.0    1343468      19.192046
# 4       광주  2011   1  12        3        2.0     737858      10.984634
# ...    ...   ...  ..  ..      ...        ...        ...            ...
# 31581   전남  2016  31  12        5        NaN     952025      25.227174
# 31582   전북  2016  31  12        5        NaN     937286      21.548385
# 31583   제주  2016  31  12        5        NaN     319052      16.552474
# 31584   충남  2016  31  12        5        NaN    1031962      19.719912
# 31585   충북  2016  31  12        5        NaN     788385      17.822003
#
#             so2       pm10        o3  rhm_min_avg_dif    avg_ta  min_max_Ta  \
# 0      0.003307  15.678261  0.027986        16.669545  1.281944    3.845070
# 1      0.002937  13.474891  0.024401        14.113793  5.360377    5.413208
# 2      0.002409  16.193461  0.027836         9.783333  6.394872    3.112821
# 3      0.003815  12.743785  0.027465        14.400000  4.429091    3.338182
# 4      0.002166   8.566667  0.021888        12.066667  6.240000    3.840000
# ...         ...        ...       ...              ...       ...         ...
# 31581  0.005431  34.282500  0.025507        21.753535  2.539189   10.937838
# 31582  0.003583  44.546347  0.021604        15.777778  1.012903    9.300000
# 31583  0.001490  24.247294  0.039094        22.135484  3.997143    7.931429
# 31584  0.002906  43.536458  0.019109        17.345000  2.663636    7.596970
# 31585  0.005038  50.466667  0.010403        17.330000 -1.018519    9.451852
#
#             avg_ps    sum_rn
# 0      1027.575000  3.038889
# 1      1025.875000  0.009434
# 2      1023.921429  1.789474
# 3      1026.137500  2.185965
# 4      1022.900000  3.200000
# ...            ...       ...
# 31581  1030.607692  0.000000
# 31582  1030.586667  0.000000
# 31583  1029.900000  0.000000
# 31584  1030.100000  0.045455
# 31585  1031.400000  0.000000
#
# [31586 rows x 16 columns]

# %%
test_female2 = test_female[test_female['yyyy'].astype(str).str.contains('2016')].reset_index(drop=True)#2016년만 추출
test_female2
# Out:
#      area  yyyy  dd  mm  weekday  frequency  total_pop  elderly_ratio  \
# 0      강원  2016   1   1        4        NaN     768008      19.916980
# 1      경기  2016   1   1        4        NaN    6229840      12.194759
# 2      경남  2016   1   1        4        NaN    1669577      16.753405
# 3      경북  2016   1   1        4        NaN    1344592      21.253882
# 4      광주  2016   1   1        4        NaN     742807      13.091826
# ...   ...   ...  ..  ..      ...        ...        ...            ...
# 6217   전남  2016  31  12        5        NaN     952025      25.227174
# 6218   전북  2016  31  12        5        NaN     937286      21.548385
# 6219   제주  2016  31  12        5        NaN     319052      16.552474
# 6220   충남  2016  31  12        5        NaN    1031962      19.719912
# 6221   충북  2016  31  12        5        NaN     788385      17.822003
#
#            so2       pm10        o3  rhm_min_avg_dif    avg_ta  min_max_Ta  \
# 0     0.005067  54.629545  0.024237        19.665950 -1.454167   10.104167
# 1     0.005282  79.033906  0.014370        20.108824 -0.091837   10.661702
# 2     0.004755  55.186508  0.029582        31.638889  0.815000   13.610000
# 3     0.006256  62.858333  0.033232        28.396296  0.371429   13.244643
# 4     0.002750  57.875000  0.025175        23.400000  1.300000   10.300000
# ...        ...        ...       ...              ...       ...         ...
# 6217  0.005431  34.282500  0.025507        21.753535  2.539189   10.937838
# 6218  0.003583  44.546347  0.021604        15.777778  1.012903    9.300000
# 6219  0.001490  24.247294  0.039094        22.135484  3.997143    7.931429
# 6220  0.002906  43.536458  0.019109        17.345000  2.663636    7.596970
# 6221  0.005038  50.466667  0.010403        17.330000 -1.018519    9.451852
#
#            avg_ps    sum_rn
# 0     1030.230000  0.000000
# 1     1031.633333  0.000000
# 2     1031.175000  0.000000
# 3     1030.309524  0.000000
# 4     1032.200000  0.000000
# ...           ...       ...
# 6217  1030.607692  0.000000
# 6218  1030.586667  0.000000
# 6219  1029.900000  0.000000
# 6220  1030.100000  0.045455
# 6221  1031.400000  0.000000
#
# [6222 rows x 16 columns]

# %%
test_female3 = test_female2.drop(columns=['frequency','yyyy','dd'])

# %%
final_model = finalize_model(et_female)
prediction_female = predict_model(final_model, data = test_female3)

# %%
prediction_female[['Label']]
# Out:
#       Label
# 0      1.03
# 1      4.45
# 2      2.11
# 3      1.93
# 4      0.92
# ...     ...
# 6217   1.64
# 6218   1.58
# 6219   0.28
# 6220   1.15
# 6221   1.24
#
# [6222 rows x 1 columns]

# %%
prediction_female['Label'] = prediction_female['Label'].round(0)
prediction_female[['Label']]
# Out:
#       Label
# 0       1.0
# 1       4.0
# 2       2.0
# 3       2.0
# 4       1.0
# ...     ...
# 6217    2.0
# 6218    2.0
# 6219    0.0
# 6220    1.0
# 6221    1.0
#
# [6222 rows x 1 columns]

# %% [markdown]
# # 남자 여자 예측 데이터 합치기

# %%
hap_male = pd.concat([test_male2[['area','yyyy','mm','dd']], prediction_male['Label']], axis=1)
hap_male['sex'] = 1
hap_male
# Out:
#      area  yyyy  mm  dd  Label  sex
# 0      강원  2016   1   1    1.0    1
# 1      경기  2016   1   1    4.0    1
# 2      경남  2016   1   1    2.0    1
# 3      경북  2016   1   1    2.0    1
# 4      광주  2016   1   1    1.0    1
# ...   ...   ...  ..  ..    ...  ...
# 6217   전남  2016  12  31    1.0    1
# 6218   전북  2016  12  31    2.0    1
# 6219   제주  2016  12  31    1.0    1
# 6220   충남  2016  12  31    1.0    1
# 6221   충북  2016  12  31    1.0    1
#
# [6222 rows x 6 columns]

# %%
hap_female = pd.concat([test_female2[['area','yyyy','mm','dd']], prediction_female['Label']], axis=1)
hap_female['sex'] = 2
hap_female
# Out:
#      area  yyyy  mm  dd  Label  sex
# 0      강원  2016   1   1    1.0    2
# 1      경기  2016   1   1    4.0    2
# 2      경남  2016   1   1    2.0    2
# 3      경북  2016   1   1    2.0    2
# 4      광주  2016   1   1    1.0    2
# ...   ...   ...  ..  ..    ...  ...
# 6217   전남  2016  12  31    2.0    2
# 6218   전북  2016  12  31    2.0    2
# 6219   제주  2016  12  31    0.0    2
# 6220   충남  2016  12  31    1.0    2
# 6221   충북  2016  12  31    1.0    2
#
# [6222 rows x 6 columns]

# %%
verify = pd.read_csv('./edited_data/2-2_검증데이터셋.csv', encoding='cp949')
verify
# Out:
#          yyyymmdd area  sex  frequency
# 0      2016-01-01   강원    1        NaN
# 1      2016-01-01   경기    1        NaN
# 2      2016-01-01   경남    1        NaN
# 3      2016-01-01   경북    1        NaN
# 4      2016-01-01   광주    1        NaN
# ...           ...  ...  ...        ...
# 12439  2016-12-31   전남    2        NaN
# 12440  2016-12-31   전북    2        NaN
# 12441  2016-12-31   제주    2        NaN
# 12442  2016-12-31   충남    2        NaN
# 12443  2016-12-31   충북    2        NaN
#
# [12444 rows x 4 columns]

# %%
hap_male['yyyy'] = hap_male['yyyy'].astype('int')
hap_male['mm'] = hap_male['mm'].astype('int')
hap_male['dd'] = hap_male['dd'].astype('int')

hap_female['yyyy'] = hap_female['yyyy'].astype('int')
hap_female['mm'] = hap_female['mm'].astype('int')
hap_female['dd'] = hap_female['dd'].astype('int')

# %%
hap_male['dateInt']=hap_male['yyyy'].astype(str) + hap_male['mm'].astype(str).str.zfill(2)+ hap_male['dd'].astype(str).str.zfill(2)
hap_male['date'] = pd.to_datetime(hap_male['dateInt'], format='%Y%m%d')
hap_male.drop(columns=['dateInt'], inplace=True)

hap_female['dateInt']=hap_female['yyyy'].astype(str) + hap_female['mm'].astype(str).str.zfill(2)+ hap_female['dd'].astype(str).str.zfill(2)
hap_female['date'] = pd.to_datetime(hap_female['dateInt'], format='%Y%m%d')
hap_female.drop(columns=['dateInt'], inplace=True)

# %%
hap_male.sort_values(['date', 'area']).reset_index(drop=True)
hap_female.sort_values(['date', 'area']).reset_index(drop=True)
# Out:
#      area  yyyy  mm  dd  Label  sex       date
# 0      강원  2016   1   1    1.0    2 2016-01-01
# 1      경기  2016   1   1    4.0    2 2016-01-01
# 2      경남  2016   1   1    2.0    2 2016-01-01
# 3      경북  2016   1   1    2.0    2 2016-01-01
# 4      광주  2016   1   1    1.0    2 2016-01-01
# ...   ...   ...  ..  ..    ...  ...        ...
# 6217   전남  2016  12  31    2.0    2 2016-12-31
# 6218   전북  2016  12  31    2.0    2 2016-12-31
# 6219   제주  2016  12  31    0.0    2 2016-12-31
# 6220   충남  2016  12  31    1.0    2 2016-12-31
# 6221   충북  2016  12  31    1.0    2 2016-12-31
#
# [6222 rows x 7 columns]

# %%
hap = pd.concat([hap_male, hap_female], axis=0).reset_index(drop=True)
hap
# Out:
#       area  yyyy  mm  dd  Label  sex       date
# 0       강원  2016   1   1    1.0    1 2016-01-01
# 1       경기  2016   1   1    4.0    1 2016-01-01
# 2       경남  2016   1   1    2.0    1 2016-01-01
# 3       경북  2016   1   1    2.0    1 2016-01-01
# 4       광주  2016   1   1    1.0    1 2016-01-01
# ...    ...   ...  ..  ..    ...  ...        ...
# 12439   전남  2016  12  31    2.0    2 2016-12-31
# 12440   전북  2016  12  31    2.0    2 2016-12-31
# 12441   제주  2016  12  31    0.0    2 2016-12-31
# 12442   충남  2016  12  31    1.0    2 2016-12-31
# 12443   충북  2016  12  31    1.0    2 2016-12-31
#
# [12444 rows x 7 columns]

# %%
verify['frequency'] = hap['Label']
verify
# Out:
#          yyyymmdd area  sex  frequency
# 0      2016-01-01   강원    1        1.0
# 1      2016-01-01   경기    1        4.0
# 2      2016-01-01   경남    1        2.0
# 3      2016-01-01   경북    1        2.0
# 4      2016-01-01   광주    1        1.0
# ...           ...  ...  ...        ...
# 12439  2016-12-31   전남    2        2.0
# 12440  2016-12-31   전북    2        2.0
# 12441  2016-12-31   제주    2        0.0
# 12442  2016-12-31   충남    2        1.0
# 12443  2016-12-31   충북    2        1.0
#
# [12444 rows x 4 columns]

# %%
verify.to_csv('220023_0728.csv', encoding='cp949')
