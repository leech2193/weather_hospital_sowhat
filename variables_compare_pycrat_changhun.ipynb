# %%
import pandas as pd
from itertools import *
from pycaret.regression import *

# %%
dataset2 = pd.read_csv('./hospital_male_0725.csv', encoding='cp949')
dataset2.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
fixed_df = dataset2[['area', 'mm', 'frequency','total_pop', 'elderly_ratio','so2','pm10','rhm_min_avg_dif','min_max_Ta','avg_ps']]

sub_df = [ dataset2[['o3']], dataset2[['avg_age']], dataset2[['avg_ta']], dataset2[['sum_gsr']], dataset2[['sum_rn']], dataset2[['avg_rhm']] ]
sub_list = list(combinations(sub_df, 2))
sub_list[2][0]

for i in range(len(sub_df)):
    dataset_df = fixed_df.copy()
    sub_list = list(combinations(sub_df, i+1))
    for j in range(len(sub_list)):
        
        for k in sub_list[j]:
            dataset_df = pd.concat([dataset_df,k], axis=1)
        
        print(dataset_df.columns)
        data = dataset_df.sample(frac=0.9, random_state=786) 
        data_unseen = dataset_df.drop(data.index) 

        data.reset_index(drop=True, inplace=True) 
        data_unseen.reset_index(drop=True, inplace=True) 

        print('Data for Modeling: ' + str(data.shape)) 
        print('Unseen Data For Predictions: ' + str(data_unseen.shape)) 
        
        s = setup(data, target = 'frequency', session_id=123)
        
        best_model_5 = compare_models(sort='RMSE', n_select = 5)
        
        final_model = finalize_model(best_model_5[0])
        prediction = predict_model(final_model, data = data_unseen)
        print(prediction['Label'])
# Out:
# Index(['area', 'mm', 'frequency', 'total_pop', 'elderly_ratio', 'so2', 'pm10',
#        'rhm_min_avg_dif', 'min_max_Ta', 'avg_ps', 'o3'],
#       dtype='object')
# Data for Modeling: (22353, 11)
# Unseen Data For Predictions: (2484, 11)
# <style type="text/css">
# #T_a8087_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a8087">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8087_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a8087_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8087_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8087_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a8087_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8087_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a8087_row1_col1" class="data row1 col1" >frequency</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8087_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a8087_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8087_row3_col0" class="data row3 col0" >Data shape</td>
#       <td id="T_a8087_row3_col1" class="data row3 col1" >(22353, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8087_row4_col0" class="data row4 col0" >Train data shape</td>
#       <td id="T_a8087_row4_col1" class="data row4 col1" >(15647, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a8087_row5_col0" class="data row5 col0" >Test data shape</td>
#       <td id="T_a8087_row5_col1" class="data row5 col1" >(6706, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a8087_row6_col0" class="data row6 col0" >Numeric features</td>
#       <td id="T_a8087_row6_col1" class="data row6 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a8087_row7_col0" class="data row7 col0" >Categorical features</td>
#       <td id="T_a8087_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a8087_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_a8087_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a8087_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_a8087_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a8087_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_a8087_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a8087_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_a8087_row11_col1" class="data row11 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a8087_row12_col0" class="data row12 col0" >Maximum one-hot encoding</td>
#       <td id="T_a8087_row12_col1" class="data row12 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a8087_row13_col0" class="data row13 col0" >Encoding method</td>
#       <td id="T_a8087_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a8087_row14_col0" class="data row14 col0" >Low variance threshold</td>
#       <td id="T_a8087_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a8087_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_a8087_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a8087_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_a8087_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a8087_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_a8087_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a8087_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_a8087_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a8087_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_a8087_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a8087_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_a8087_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a8087_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a8087_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_a8087_row21_col1" class="data row21 col1" >94b5</td>
#     </tr>
#   </tbody>
# </table>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                 23:44:17
# Status     . . . . . . . . . . . . . . . . . .         Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Regressor
# <style type="text/css">
# #T_f86fb th {
#   text-align: left;
# }
# #T_f86fb_row0_col0, #T_f86fb_row0_col1, #T_f86fb_row0_col2, #T_f86fb_row0_col3, #T_f86fb_row0_col4, #T_f86fb_row0_col5, #T_f86fb_row0_col6, #T_f86fb_row0_col7, #T_f86fb_row1_col0, #T_f86fb_row1_col1, #T_f86fb_row1_col2, #T_f86fb_row1_col3, #T_f86fb_row1_col4, #T_f86fb_row1_col5, #T_f86fb_row1_col6, #T_f86fb_row1_col7, #T_f86fb_row2_col0, #T_f86fb_row2_col1, #T_f86fb_row2_col2, #T_f86fb_row2_col3, #T_f86fb_row2_col4, #T_f86fb_row2_col5, #T_f86fb_row2_col6, #T_f86fb_row2_col7, #T_f86fb_row3_col0, #T_f86fb_row3_col1, #T_f86fb_row3_col2, #T_f86fb_row3_col3, #T_f86fb_row3_col4, #T_f86fb_row3_col5, #T_f86fb_row3_col6, #T_f86fb_row3_col7, #T_f86fb_row4_col0, #T_f86fb_row4_col1, #T_f86fb_row4_col2, #T_f86fb_row4_col3, #T_f86fb_row4_col4, #T_f86fb_row4_col5, #T_f86fb_row4_col6, #T_f86fb_row4_col7, #T_f86fb_row5_col0, #T_f86fb_row5_col1, #T_f86fb_row5_col2, #T_f86fb_row5_col3, #T_f86fb_row5_col4, #T_f86fb_row5_col5, #T_f86fb_row5_col6, #T_f86fb_row5_col7, #T_f86fb_row6_col0, #T_f86fb_row6_col1, #T_f86fb_row6_col2, #T_f86fb_row6_col3, #T_f86fb_row6_col4, #T_f86fb_row6_col5, #T_f86fb_row6_col6, #T_f86fb_row6_col7, #T_f86fb_row7_col0, #T_f86fb_row7_col1, #T_f86fb_row7_col2, #T_f86fb_row7_col3, #T_f86fb_row7_col4, #T_f86fb_row7_col5, #T_f86fb_row7_col6, #T_f86fb_row7_col7, #T_f86fb_row8_col0, #T_f86fb_row8_col1, #T_f86fb_row8_col2, #T_f86fb_row8_col3, #T_f86fb_row8_col4, #T_f86fb_row8_col5, #T_f86fb_row8_col6, #T_f86fb_row8_col7, #T_f86fb_row9_col0, #T_f86fb_row9_col1, #T_f86fb_row9_col2, #T_f86fb_row9_col3, #T_f86fb_row9_col4, #T_f86fb_row9_col5, #T_f86fb_row9_col6, #T_f86fb_row9_col7, #T_f86fb_row10_col0, #T_f86fb_row10_col1, #T_f86fb_row10_col2, #T_f86fb_row10_col3, #T_f86fb_row10_col4, #T_f86fb_row10_col5, #T_f86fb_row10_col6, #T_f86fb_row10_col7, #T_f86fb_row11_col0, #T_f86fb_row11_col1, #T_f86fb_row11_col2, #T_f86fb_row11_col3, #T_f86fb_row11_col4, #T_f86fb_row11_col5, #T_f86fb_row11_col6, #T_f86fb_row11_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_f86fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f86fb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f86fb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f86fb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f86fb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f86fb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f86fb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f86fb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f86fb_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f86fb_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_f86fb_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_f86fb_row0_col1" class="data row0 col1" >0.9166</td>
#       <td id="T_f86fb_row0_col2" class="data row0 col2" >1.5917</td>
#       <td id="T_f86fb_row0_col3" class="data row0 col3" >1.2613</td>
#       <td id="T_f86fb_row0_col4" class="data row0 col4" >0.4439</td>
#       <td id="T_f86fb_row0_col5" class="data row0 col5" >0.4925</td>
#       <td id="T_f86fb_row0_col6" class="data row0 col6" >0.4417</td>
#       <td id="T_f86fb_row0_col7" class="data row0 col7" >0.1840</td>
#     </tr>
#     <tr>
#       <th id="T_f86fb_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_f86fb_row1_col0" class="data row1 col0" >Ridge Regression</td>
#       <td id="T_f86fb_row1_col1" class="data row1 col1" >0.9166</td>
#       <td id="T_f86fb_row1_col2" class="data row1 col2" >1.5916</td>
#       <td id="T_f86fb_row1_col3" class="data row1 col3" >1.2613</td>
#       <td id="T_f86fb_row1_col4" class="data row1 col4" >0.4440</td>
#       <td id="T_f86fb_row1_col5" class="data row1 col5" >0.4924</td>
#       <td id="T_f86fb_row1_col6" class="data row1 col6" >0.4415</td>
#       <td id="T_f86fb_row1_col7" class="data row1 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_f86fb_level0_row2" class="row_heading level0 row2" >lar</th>
#       <td id="T_f86fb_row2_col0" class="data row2 col0" >Least Angle Regression</td>
#       <td id="T_f86fb_row2_col1" class="data row2 col1" >0.9166</td>
#       <td id="T_f86fb_row2_col2" class="data row2 col2" >1.5917</td>
#       <td id="T_f86fb_row2_col3" class="data row2 col3" >1.2613</td>
#       <td id="T_f86fb_row2_col4" class="data row2 col4" >0.4439</td>
#       <td id="T_f86fb_row2_col5" class="data row2 col5" >0.4925</td>
#       <td id="T_f86fb_row2_col6" class="data row2 col6" >0.4417</td>
#       <td id="T_f86fb_row2_col7" class="data row2 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_f86fb_level0_row3" class="row_heading level0 row3" >br</th>
#       <td id="T_f86fb_row3_col0" class="data row3 col0" >Bayesian Ridge</td>
#       <td id="T_f86fb_row3_col1" class="data row3 col1" >0.9174</td>
#       <td id="T_f86fb_row3_col2" class="data row3 col2" >1.5921</td>
#       <td id="T_f86fb_row3_col3" class="data row3 col3" >1.2614</td>
#       <td id="T_f86fb_row3_col4" class="data row3 col4" >0.4438</td>
#       <td id="T_f86fb_row3_col5" class="data row3 col5" >0.4925</td>
#       <td id="T_f86fb_row3_col6" class="data row3 col6" >0.4414</td>
#       <td id="T_f86fb_row3_col7" class="data row3 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_f86fb_level0_row4" class="row_heading level0 row4" >omp</th>
#       <td id="T_f86fb_row4_col0" class="data row4 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_f86fb_row4_col1" class="data row4 col1" >0.9146</td>
#       <td id="T_f86fb_row4_col2" class="data row4 col2" >1.5922</td>
#       <td id="T_f86fb_row4_col3" class="data row4 col3" >1.2615</td>
#       <td id="T_f86fb_row4_col4" class="data row4 col4" >0.4438</td>
#       <td id="T_f86fb_row4_col5" class="data row4 col5" >0.4924</td>
#       <td id="T_f86fb_row4_col6" class="data row4 col6" >0.4395</td>
#       <td id="T_f86fb_row4_col7" class="data row4 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_f86fb_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_f86fb_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_f86fb_row5_col1" class="data row5 col1" >0.8837</td>
#       <td id="T_f86fb_row5_col2" class="data row5 col2" >1.6707</td>
#       <td id="T_f86fb_row5_col3" class="data row5 col3" >1.2921</td>
#       <td id="T_f86fb_row5_col4" class="data row5 col4" >0.4163</td>
#       <td id="T_f86fb_row5_col5" class="data row5 col5" >0.5085</td>
#       <td id="T_f86fb_row5_col6" class="data row5 col6" >0.4343</td>
#       <td id="T_f86fb_row5_col7" class="data row5 col7" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_f86fb_level0_row6" class="row_heading level0 row6" >lasso</th>
#       <td id="T_f86fb_row6_col0" class="data row6 col0" >Lasso Regression</td>
#       <td id="T_f86fb_row6_col1" class="data row6 col1" >0.9609</td>
#       <td id="T_f86fb_row6_col2" class="data row6 col2" >1.6737</td>
#       <td id="T_f86fb_row6_col3" class="data row6 col3" >1.2934</td>
#       <td id="T_f86fb_row6_col4" class="data row6 col4" >0.4152</td>
#       <td id="T_f86fb_row6_col5" class="data row6 col5" >0.5103</td>
#       <td id="T_f86fb_row6_col6" class="data row6 col6" >0.4092</td>
#       <td id="T_f86fb_row6_col7" class="data row6 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_f86fb_level0_row7" class="row_heading level0 row7" >en</th>
#       <td id="T_f86fb_row7_col0" class="data row7 col0" >Elastic Net</td>
#       <td id="T_f86fb_row7_col1" class="data row7 col1" >0.9607</td>
#       <td id="T_f86fb_row7_col2" class="data row7 col2" >1.6736</td>
#       <td id="T_f86fb_row7_col3" class="data row7 col3" >1.2934</td>
#       <td id="T_f86fb_row7_col4" class="data row7 col4" >0.4153</td>
#       <td id="T_f86fb_row7_col5" class="data row7 col5" >0.5103</td>
#       <td id="T_f86fb_row7_col6" class="data row7 col6" >0.4095</td>
#       <td id="T_f86fb_row7_c
# Processing:   0%|          | 0/85 [00:00<?, ?it/s]
