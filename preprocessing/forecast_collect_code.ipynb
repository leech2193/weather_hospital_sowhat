# %%
import numpy      as np
import pandas     as pd
import seaborn    as sns
from sklearn.model_selection   import train_test_split
import matplotlib.pyplot as plt
import missingno as msno
import os
import glob

# %%
# path = "C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012/강원"
# file_list = os.listdir(path)
# file_list_py = [file for file in file_list if file.endswith(".csv")]

# %%
# file_list_py

# %%
# subfolders_nm = pd.DataFrame([ f.name for f in os.scandir('C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/') if f.is_dir()  ], columns = ['dir_name'])
# subfolders_frm = pd.concat([subfolders_nm], axis=1)

# %%
# subfolders_frm

# %%
# output = glob.glob('C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/*')
# output

# %%
import os
preprocessing_lst = []
dir_path = "C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/"
for (root, directories, files) in os.walk(dir_path):
    for file in files:
        if '.csv' in file:
            file_path = os.path.join(root, file)
            preprocessing_lst.append(file_path)

# %%
preprocessing_lst
# Out:
# ['C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_12시간강수량_201201_201212.csv',
#  'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_12시간신적설_201201_201212.csv',
#  'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_3시간기온_201201_201212.csv',
#  'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_강수형태_201201_201212.csv',
#  'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_강수확률_201201_201212.csv',
#  'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_습도_201201_201212.csv',
#  'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_일최고기온_201201_201212.csv',
#  'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_일최저기온_201201_201212.csv',
#  'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_파고_201201_201212.csv',
# ...

# %%
refined_data_lst = []
for x in preprocessing_lst:
    if ("강수" or "기온" or "습도" or "일사량") in x:
        refined_data_lst.append(x)
print(refined_data_lst)
# Out:
# ['C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_12시간강수량_201201_201212.csv', 'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_강수형태_201201_201212.csv', 'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\갈말읍_강수확률_201201_201212.csv', 'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\대관령면_12시간강수량_201201_201212.csv', 'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\대관령면_강수형태_201201_201212.csv', 'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\대관령면_강수확률_201201_201212.csv', 'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\명륜1동_12시간강수량_201201_201212.csv', 'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\명륜1동_강수형태_201201_201212.csv', 'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\명륜1동_강수확률_201201_201212.csv', 'C:/Users/Oh_Yeun_Seok/Desktop/기상콘테스트/예보데이터/2-2날씨빅데이터 콘테스트/2012\\강원\\사천면_12시간강수량_201201_201212.csv',
# ...

# %%
print(len(preprocessing_lst))
print(len(refined_data_lst))
# Out:
# 5892
# 1521
