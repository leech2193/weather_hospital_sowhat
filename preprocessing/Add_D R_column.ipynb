# %%
import tensorflow as tf
import numpy      as np
import pandas     as pd
import seaborn    as sns
from sklearn.model_selection   import train_test_split
import matplotlib.pyplot as plt
import missingno as msno

# %%
hospital_male_frm = pd.read_csv("../content/hospital_male.csv", encoding='cp949')
hospital_female_frm =  pd.read_csv("../content/hospital_female.csv", encoding='cp949')

# %%
hospital_male_frm

# %%
# hospital_male_frm.drop('Unnamed: 0', axis = 'columns', inplace =True)
# hospital_female_frm.drop('Unnamed: 0', axis = 'columns', inplace =True)

# %%
# 지역 인구대비 질환자 발생비율 컬럼. 10**6을 한 이유는 광역시, 도 단위가 100만 단위로 떨어지기때문에 eda를 위해 곱함
hospital_male_frm["D/R"] = (hospital_male_frm["frequency"]/hospital_male_frm["total_pop"])*(10**6)
hospital_female_frm["D/R"] = (hospital_female_frm["frequency"]/hospital_female_frm["total_pop"])*(10**6)

# %%
display(hospital_female_frm[["area","tma","D/R"]])
print()
display(hospital_male_frm[["area","tma","D/R"]])

# %%
#질환발생자 없는 날 확인
fail1_frm = hospital_male_frm[hospital_male_frm["D/R"]<=0.001]
fail2_frm = hospital_female_frm[hospital_female_frm["D/R"]<=0.001]
print()
display(fail1_frm[["D/R"]])
print()
display(fail2_frm[["D/R"]])
# Out:
#        D/R
# 4      0.0
# 9      0.0
# 10     0.0
# 14     0.0
# 15     0.0
# ...    ...
# 24829  0.0
# 24830  0.0
# 24832  0.0
# 24834  0.0
# 24835  0.0
#
# [9152 rows x 1 columns]
#        D/R
# 5      0.0
# 9      0.0
# 10     0.0
# 14     0.0
# 17     0.0
# ...    ...
# 24831  0.0
# 24833  0.0
# 24834  0.0
# 24835  0.0
# 24836  0.0
#
# [9045 rows x 1 columns]
